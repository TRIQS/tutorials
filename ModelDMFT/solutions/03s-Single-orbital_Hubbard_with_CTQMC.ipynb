# %% [markdown]
# Single-orbital Hubbard model
# ============================
#
# In this notebook you will reproduce the Bethe lattice DMFT that we did earlier with IPT,
# but you will use the CTHYB solver to find the solution of the impurity problem. We will
# consider the problem at half-filling again.
#
# In general it is a good idea to develop the script in the notebook, because it is very convenient to find bugs and to quickly come to a working code. In the beginning you should use a small number of Monte Carlo iterations (say 1000) so that the code runs quickly. Your first main goal is to have a functional script. However, once the script is done, we recommend that you do longer runs (production runs) from a shell. It will be easier for you to see the progress of the Monte Carlo solver. Think about saving the relevant data to an archive and then go back to the notebook when it comes to analyzing and plotting the results. This is usually how things are done: elaboration of the scripts and analysis of the data from the notebook, production from a shell.
#
# In order to run your script from a shell, open a terminal and go in the tutorial directory.
# This is where you should edit your production script. Let's call it `run_dmft.py`. Use your favourite editor (e.g. `vi` or `gedit`) to create the script `run_dmft.py`.
#
# When the script is written save it and run it. You can:
#
# - run it directly from the shell to see the Monte Carlo progress:
#
# `>>> python run_dmft.py`
#
# - run the following command in a notebook cell.
#
# `%run run_dmft.py`
#
# That's it! When the run is done and data has been saved into an archive, you can go back to the notebook and read the archive in order to analyze or plot the results.

# %% [markdown]
# <i class="fa fa-gear fa-x" style="color: #186391"></i> Exercise 1
# ----------
#
# Write a DMFT loop, like you did earlier but using the CTHYB solver.
#
# *Hint*: It is useful to symmetrize the Green's function (make the `up` and `down` components the same) to avoid some artificial polarization of the system close to the Mott transition. You might want to enforce the `up`-`down` symmetry on `S.G` just before the self-consistency condition. In order
# to have reasonable data you should have at least 10000 cycles.

# %% [markdown]
# Solution 1
# ----------
#
# The solution of this exercise is in the script `scripts/one_band.py` in the tutorial directory. We have loaded this script into the cell below.

# %%
# %load scripts/one_band.py
from triqs.gf import *
from triqs.operators import *
from h5 import *
from triqs_cthyb import Solver
import numpy as np

# Parameters of the model
t = 1.0
beta = 10
n_loops = 10

# Construct the impurity solver
S = Solver(beta = beta, gf_struct = [('up',1), ('down',1)] )

# I run for several values of U
for U in np.arange(1.0, 9.0):
    print('U =', U)

    # This is a first guess for G
    S.G_iw << SemiCircular(2*t)

    # DMFT loop with self-consistency
    for i in range(n_loops):

        print("\n\nIteration = %i / %i" % (i+1, n_loops))

        # Symmetrize the Green's function and use self-consistency
        g = 0.5 * ( S.G_iw['up'] + S.G_iw['down'] )
        for name, g0 in S.G0_iw:
            g0 << inverse( iOmega_n + U/2.0 - t**2 * g )

        # Solve the impurity problem
        S.solve(h_int = U * n('up',0) * n('down',0),   # Local Hamiltonian
            n_cycles  = 10000,                           # Number of QMC cycles
            n_warmup_cycles = 5000,                      # Warmup cycles
            )

        # Save iteration in archive
        with HDFArchive("data/one_band/half-U%.2f.h5"%U) as A:
            A['G-%i'%i] = S.G_iw
            A['Sigma-%i'%i] = S.Sigma_iw
# Out:
# Warning: could not identify MPI environment!
# U = 1.0
#
#
# Iteration = 1 / 10
# Starting serial run at: 2025-08-31 22:15:09.165935
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -0.5*c_dag('down',0)*c('down',0) + -0.5*c_dag('up',0)*c('up',0) + 1*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:09  30% ETA 00:00:00 cycle 1540 of 5000
# 22:15:09 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:09  15% ETA 00:00:00 cycle 1511 of 10000
# 22:15:10 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00113935
# Average order         | 0.000232928
# Average sign          | 0.000237964
# G_tau measure         | 0.0023957
# Total measure time    | 0.00400594
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.134194
#   Move  Insert Delta_up: 0.135137
#   Move  Insert Delta_down: 0.133256
# Move set Remove two operators: 0.134078
#   Move  Remove Delta_up: 0.134495
#   Move  Remove Delta_down: 0.13366
# Move set Insert four operators: 0.0237206
#   Move  Insert Delta_up_up: 0.0263818
#   Move  Insert Delta_up_down: 0.0215067
#   Move  Insert Delta_down_up: 0.0192815
#   Move  Insert Delta_down_down: 0.0276912
# Move set Remove four operators: 0.0240728
#   Move  Remove Delta_up_up: 0.027297
#   Move  Remove Delta_up_down: 0.0201105
#   Move  Remove Delta_down_up: 0.0206622
#   Move  Remove Delta_down_down: 0.0282551
# Move  Shift one operator: 0.83864
# [Rank 0] Warmup lasted: 0.32589 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.654529 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 8.1807
# Auto-correlation time: 3.07816
#
#
# Iteration = 2 / 10
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -0.5*c_dag('down',0)*c('down',0) + -0.5*c_dag('up',0)*c('up',0) + 1*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:10  31% ETA 00:00:00 cycle 1568 of 5000
# 22:15:10 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:10  15% ETA 00:00:00 cycle 1558 of 10000
# 22:15:11 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00111321
# Average order         | 0.000235032
# Average sign          | 0.000237235
# G_tau measure         | 0.00172376
# Total measure time    | 0.00330924
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.137529
#   Move  Insert Delta_up: 0.138608
#   Move  Insert Delta_down: 0.136454
# Move set Remove two operators: 0.135646
#   Move  Remove Delta_up: 0.137095
#   Move  Remove Delta_down: 0.134192
# Move set Insert four operators: 0.0248063
#   Move  Insert Delta_up_up: 0.029023
#   Move  Insert Delta_up_down: 0.0202982
#   Move  Insert Delta_down_up: 0.0212102
#   Move  Insert Delta_down_down: 0.0286456
# Move set Remove four operators: 0.0258106
#   Move  Remove Delta_up_up: 0.0300133
#   Move  Remove Delta_up_down: 0.0207927
#   Move  Remove Delta_down_up: 0.0216027
#   Move  Remove Delta_down_down: 0.0308751
# Move  Shift one operator: 0.82967
# [Rank 0] Warmup lasted: 0.321508 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.650892 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 8.0726
# Auto-correlation time: 2.95457
#
#
# Iteration = 3 / 10
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -0.5*c_dag('down',0)*c('down',0) + -0.5*c_dag('up',0)*c('up',0) + 1*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:11  30% ETA 00:00:00 cycle 1536 of 5000
# 22:15:11 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:11  15% ETA 00:00:00 cycle 1536 of 10000
# 22:15:12 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00107717
# Average order         | 0.000230832
# Average sign          | 0.000232963
# G_tau measure         | 0.00165844
# Total measure time    | 0.00319941
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.136691
#   Move  Insert Delta_up: 0.136118
#   Move  Insert Delta_down: 0.137262
# Move set Remove two operators: 0.135948
#   Move  Remove Delta_up: 0.135115
#   Move  Remove Delt
#
# Iteration = 4 / 10
# a_down: 0.136781
# Move set Insert four operators: 0.024431
#   Move  Insert Delta_up_up: 0.0279642
#   Move  Insert Delta_up_down: 0.0212578
#   Move  Insert Delta_down_up: 0.021372
#   Move  Insert Delta_down_down: 0.0270992
# Move set Remove four operators: 0.0251374
#   Move  Remove Delta_up_up: 0.0298838
#   Move  Remove Delta_up_down: 0.0205143
#   Move  Remove Delta_down_up: 0.0209849
#   Move  Remove Delta_down_down: 0.0291752
# Move  Shift one operator: 0.832854
# [Rank 0] Warmup lasted: 0.322879 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.652348 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 8.1617
# Auto-correlation time: 1.88829
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
#
#
# Iteration = 5 / 10
# -0.5*c_dag('down',0)*c('down',0) + -0.5*c_dag('up',0)*c('up',0) + 1*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:12  30% ETA 00:00:00 cycle 1547 of 5000
# 22:15:12 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:12  15% ETA 00:00:00 cycle 1542 of 10000
# 22:15:13 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.0011201
# Average order         | 0.000228954
# Average sign          | 0.000231752
# G_tau measure         | 0.00254385
# Total measure time    | 0.00412465
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.137877
#   Move  Insert Delta_up: 0.13878
#   Move  Insert Delta_down: 0.136976
# Move set Remove two operators: 0.136859
#   Move  Remove Delta_up: 0.137844
#   Move  Remove Delta_down: 0.135872
# Move set Insert four operators: 0.0240401
#   Move  Insert Delta_up_up: 0.0279466
#   Move  Insert Delta_up_down: 0.0193165
#   Move  Insert Delta_down_up: 0.0205293
#   Move  Insert Delta_down_down: 0.0283427
# Move set Remove four operators: 0.0247222
#   Move  Remove Delta_up_up: 0.0272073
#   Move  Remove Delta_up_down: 0.0219802
#   Move  Remove Delta_down_up: 0.0218302
#   Move  Remove Delta_down_down: 0.0278651
# Move  Shift one operator: 0.830322
# [Rank 0] Warmup lasted: 0.323252 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.653439 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 8.1484
# Auto-correlation time: 1.59076
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
#
#
# Iteration = 6 / 10
# -0.5*c_dag('down',0)*c('down',0) + -0.5*c_dag('up',0)*c('up',0) + 1*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:13  30% ETA 00:00:00 cycle 1542 of 5000
# 22:15:13 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:13  15% ETA 00:00:00 cycle 1532 of 10000
# 22:15:14 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00112065
# Average order         | 0.000230939
# Average sign          | 0.000238882
# G_tau measure         | 0.00259875
# Total measure time    | 0.00418923
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.136129
#   Move  Insert Delta_up: 0.135304
#   Move  Insert Delta_down: 0.136951
# Move set Remove two operators: 0.137127
#   Move  Remove Delta_up: 0.1367
#   Move  Remove Delta_down: 0.137554
# Move set Insert four operators: 0.024601
#   Move  Insert Delta_up_up: 0.0281926
#   Move  Insert Delta_up_down: 0.0207839
#   Move  Insert Delta_down_up: 0.0216895
#   Move  Insert Delta_down_down: 0.027688
# Move set Remove four operators: 0.0242563
#   Move  Remove Delta_up_up: 0.0271906
#   Move  Remove Delta_up_down: 0.0216098
#   Move  Remove Delta_down_up: 0.0202847
#   Move  Remove Delta_down_down: 0.0279555
# Move  Shift one operator: 0.830414
# [Rank 0] Warmup lasted: 0.323299 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.655144 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 8.1626
# Auto-correlation time: 2.51126
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
#
#
# Iteration = 7 / 10
# -0.5*c_dag('down',0)*c('down',0) + -0.5*c_dag('up',0)*c('up',0) + 1*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:14  30% ETA 00:00:00 cycle 1542 of 5000
# 22:15:14 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:14  15% ETA 00:00:00 cycle 1551 of 10000
# 22:15:15 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00113066
# Average order         | 0.000235142
# Average sign          | 0.000235742
# G_tau measure         | 0.00251736
# Total measure time    | 0.0041189
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.136631
#   Move  Insert Delta_up: 0.137952
#   Move  Insert Delta_down: 0.135314
# Move set Remove two operators: 0.138106
#   Move  Remove Delta_up: 0.13836
#   Move  Remove Delta_down: 0.137851
# Move set Insert four operators: 0.0257115
#   Move  Insert Delta_up_up: 0.029352
#   Move  Insert Delta_up_down: 0.0212757
#   Move  Insert Delta_down_up: 0.0216313
#   Move  Insert Delta_down_down: 0.030564
# Move set Remove four operators: 0.0249482
#   Move  Remove Delta_up_up: 0.0290644
#   Move  Remove Delta_up_down: 0.0214022
#   Move  Remove Delta_down_up: 0.0207806
#   Move  Remove Delta_down_down: 0.0285886
# Move  Shift one operator: 0.830217
# [Rank 0] Warmup lasted: 0.323049 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.655246 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 8.1595
# Auto-correlation time: 3.00369
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
#
#
# Iteration = 8 / 10
# -0.5*c_dag('down',0)*c('down',0) + -0.5*c_dag('up',0)*c('up',0) + 1*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:15  30% ETA 00:00:00 cycle 1548 of 5000
# 22:15:15 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:15  15% ETA 00:00:00 cycle 1567 of 10000
# 22:15:16 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00114728
# Average order         | 0.000229679
# Average sign          | 0.00023297
# G_tau measure         | 0.00249465
# Total measure time    | 0.00410458
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.138683
#   Move  Insert Delta_up: 0.138785
#   Move  Insert Delta_down: 0.138581
# Move set Remove two operators: 0.135491
#   Move  Remove Delta_up: 0.134835
#   Move  Remove Delta_down: 0.136151
# Move set Insert four operators: 0.0238837
#   Move  Insert Delta_up_up: 0.0282195
#   Move  Insert Delta_up_down: 0.0187678
#   Move  Insert Delta_down_up: 0.0213364
#   Move  Insert Delta_down_down: 0.0271656
# Move set Remove four operators: 0.0256944
#   Move  Remove Delta_up_up: 0.0296998
#   Move  Remove Delta_up_down: 0.0223175
#   Move  Remove Delta_down_up: 0.0230494
#   Move  Remove Delta_down_down: 0.0277512
# Move  Shift one operator: 0.826742
# [Rank 0] Warmup lasted: 0.323169 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.649883 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 8.0322
# Auto-correlation time: 3.10339
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
#
#
# Iteration = 9 / 10
# -0.5*c_dag('down',0)*c('down',0) + -0.5*c_dag('up',0)*c('up',0) + 1*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:16  30% ETA 00:00:00 cycle 1547 of 5000
# 22:15:16 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:16  15% ETA 00:00:00 cycle 1539 of 10000
# 22:15:17 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00110838
# Average order         | 0.000233267
# Average sign          | 0.000233021
# G_tau measure         | 0.00172841
# Total measure time    | 0.00330307
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.138506
#   Move  Insert Delta_up: 0.139623
#   Move  Insert Delta_down: 0.137394
# Move set Remove two operators: 0.138454
#   Move  Remove Delta_up: 0.136949
#   Move  Remove Delta_down: 0.139969
# Move set Insert four operators: 0.0253769
#   Move  Insert Delta_up_up: 0.0293179
#   Move  Insert Delta_up_down: 0.0211004
#   Move  Insert Delta_down_up: 0.0205091
#   Move  Insert Delta_down_down: 0.0305689
# Move set Remove four operators: 0.0253767
#   Move  Remove Delta_up_up: 0.0309133
#   Move  Remove Delta_up_down: 0.0217365
#   Move  Remove Delta_down_up: 0.0212245
#   Move  Remove Delta_down_down: 0.0276795
# Move  Shift one operator: 0.827338
# [Rank 0] Warmup lasted: 0.325045 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.648884 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 8.0508
# Auto-correlation time: 2.62123
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -0.5*c_dag('down',0)*c('down',0) + -0.5*c_dag('up',0)*c('up',0) + 1*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:17  31% ETA 00:00:00 cycle 1553 of 5000
# 22:15:17 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:17  15% ETA 00:00:00 cycle 1530 of 10000
# 22:15:18 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.0011254
# Average order         | 0.000232842
# Average sign          | 0.000229568
# G_tau measure         | 0.00241748
# Total measure time    | 0.00400529
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.137111
#   Move  Insert Delta_up: 0.138103
#   Move  Insert Delta_down: 0.136124
# Move set Remove two operators: 0.136868
#   Move  Remove Delta_up: 0.136946
#   Move  Remove Delta_down: 0.136791
# Move set Insert four operators: 0.0244609
#   Move  Insert Delta_up_up: 0.0282271
#   Move  Insert Delta_up_down: 0.0201996
#   Move  Insert Delta_down_up: 0.0211721
#   Move  Insert Delta_down_down: 0.0281887
# Move set Remove four operators: 0.0246914
#   Move  Remove Delta_up_up: 0.0285174
#   Move  Remove Delta_up_down: 0.0222497
#   Move  Remove Delta_down_up: 0.0207763
#   Move  Remove Delta_down_down: 0.0272237
# Move  Shift one operator: 0.831942
# [Rank 0] Warmup lasted: 0.324499 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.656003 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 8.1865
# Auto-correlation time: 1.6264
#
#
# Iteration = 10 / 10
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -0.5*c_dag('down',0)*c('down',0) + -0.5*c_dag('up',0)*c('up',0) + 1*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:18  30% ETA 00:00:00 cycle 1541 of 5000
# 22:15:18 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:18  15% ETA 00:00:00 cycle 1541 of 10000
# 22:15:19 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00112946
# Average order         | 0.00023187
# Average sign          | 0.000232985
# G_tau measure         | 0.00174388
# Total measure time    | 0.00333819
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.136865
#   Move  Insert Delta_up: 0.136144
#   Move  Insert Delta_down: 0.137585
# Move set Remove two operators: 0.136487
#   Move  Remove Delta_up: 0.136087
#   Move  Remove DeltaU = 2.0
# _down: 0.136888
# Move set Insert four operators: 0.0247125
#   Move  Insert Delta_up_up: 0.0291157
#   Move  Insert Delta_up_down: 0.0200999
#   Move  Insert Delta_down_up: 0.0207065
#   Move  Insert Delta_down_down: 0.0288711
# Move set Remove four operators: 0.0250504
#   Move  Remove Delta_up_up: 0.0279124
#   Move  Remove Delta_up_down: 0.0211228
#   Move  Remove Delta_down_up: 0.0220934
#   Move  Remove Delta_down_down: 0.0291107
# Move  Shift one operator: 0.830829
# [Rank 0] Warmup lasted: 0.325684 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.653293 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 8.1232
# Auto-correlation time: 2.62633
#
#
# Iteration = 1 / 10
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
#
#
# Iteration = 2 / 10
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:19  33% ETA 00:00:00 cycle 1684 of 5000
# 22:15:19 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:19  16% ETA 00:00:00 cycle 1657 of 10000
# 22:15:20 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00108526
# Average order         | 0.000232064
# Average sign          | 0.000232837
# G_tau measure         | 0.00304879
# Total measure time    | 0.00459895
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.125473
#   Move  Insert Delta_up: 0.125155
#   Move  Insert Delta_down: 0.12579
# Move set Remove two operators: 0.125671
#   Move  Remove Delta_up: 0.125471
#   Move  Remove Delta_down: 0.125871
# Move set Insert four operators: 0.0246864
#   Move  Insert Delta_up_up: 0.0268028
#   Move  Insert Delta_up_down: 0.0216412
#   Move  Insert Delta_down_up: 0.0227946
#   Move  Insert Delta_down_down: 0.0274721
# Move set Remove four operators: 0.0247316
#   Move  Remove Delta_up_up: 0.0269343
#   Move  Remove Delta_up_down: 0.0224071
#   Move  Remove Delta_down_up: 0.0220799
#   Move  Remove Delta_down_down: 0.0275138
# Move  Shift one operator: 0.698464
# [Rank 0] Warmup lasted: 0.298891 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.604475 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.6646
# Auto-correlation time: 3.28392
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:20  34% ETA 00:00:00 cycle 1701 of 5000
# 22:15:20 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:20  17% ETA 00:00:00 cycle 1719 of 10000
# 22:15:21 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00111884
# Average order         | 0.000229345
# Average sign          | 0.000234258
# G_tau measure         | 0.00236772
# Total measure time    | 0.00395016
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.130538
#   Move  Insert Delta_up: 0.131357
#   Move  Insert Delta_down: 0.129719
# Move set Remove two operators: 0.130263
#   Move  Remove Delta_up: 0.131032
#   Move  Remove Delta_down: 0.129493
# Move set Insert four operators: 0.0270564
#   Move  Insert Delta_up_up: 0.0299128
#   Move  Insert Delta_up_down: 0.0238143
#   Move  Insert Delta_down_up: 0.0254887
#   Move  Insert Delta_down_down: 0.0289647
# Move set Remove four operators: 0.0271909
#   Move  Remove Delta_up_up: 0.0297328
#   Move  Remove Delta_up_down: 0.0259022
#   Move  Remove Delta_down_up: 0.0248111
#   Move  Remove Delta_down_down: 0.028303
# Move  Shift one operator: 0.678488
# [Rank 0] Warmup lasted: 0.292889 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.592597 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.3414
# Auto-correlation time: 2.59554
#
#
# Iteration = 3 / 10
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
#
#
# Iteration = 4 / 10
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:21  34% ETA 00:00:00 cycle 1705 of 5000
# 22:15:21 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:21  16% ETA 00:00:00 cycle 1682 of 10000
# 22:15:22 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00108263
# Average order         | 0.000228878
# Average sign          | 0.00023022
# G_tau measure         | 0.0016344
# Total measure time    | 0.00317613
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.127771
#   Move  Insert Delta_up: 0.128914
#   Move  Insert Delta_down: 0.12663
# Move set Remove two operators: 0.128221
#   Move  Remove Delta_up: 0.129491
#   Move  Remove Delta_down: 0.12695
# Move set Insert four operators: 0.0256648
#   Move  Insert Delta_up_up: 0.0283026
#   Move  Insert Delta_up_down: 0.0233949
#   Move  Insert Delta_down_up: 0.0232993
#   Move  Insert Delta_down_down: 0.0276514
# Move set Remove four operators: 0.0258822
#   Move  Remove Delta_up_up: 0.0277958
#   Move  Remove Delta_up_down: 0.0234759
#   Move  Remove Delta_down_up: 0.0250552
#   Move  Remove Delta_down_down: 0.0272286
# Move  Shift one operator: 0.684272
# [Rank 0] Warmup lasted: 0.294414 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.595535 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.4618
# Auto-correlation time: 2.75014
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
#
#
# Iteration = 5 / 10
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:22  33% ETA 00:00:00 cycle 1698 of 5000
# 22:15:22 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:22  17% ETA 00:00:00 cycle 1716 of 10000
# 22:15:23 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00111296
# Average order         | 0.000227604
# Average sign          | 0.000232914
# G_tau measure         | 0.00156569
# Total measure time    | 0.00313916
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.131699
#   Move  Insert Delta_up: 0.130628
#   Move  Insert Delta_down: 0.13277
# Move set Remove two operators: 0.130431
#   Move  Remove Delta_up: 0.129478
#   Move  Remove Delta_down: 0.131386
# Move set Insert four operators: 0.0271569
#   Move  Insert Delta_up_up: 0.0281887
#   Move  Insert Delta_up_down: 0.0258805
#   Move  Insert Delta_down_up: 0.024888
#   Move  Insert Delta_down_down: 0.0296566
# Move set Remove four operators: 0.0275519
#   Move  Remove Delta_up_up: 0.0287468
#   Move  Remove Delta_up_down: 0.0255961
#   Move  Remove Delta_down_up: 0.0253231
#   Move  Remove Delta_down_down: 0.0305499
# Move  Shift one operator: 0.672073
# [Rank 0] Warmup lasted: 0.291286 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.586749 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.2379
# Auto-correlation time: 2.34046
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:23  34% ETA 00:00:00 cycle 1702 of 5000
# 22:15:23 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:23  17% ETA 00:00:00 cycle 1713 of 10000
# 22:15:24 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00111145
# Average order         | 0.000229873
# Average sign          | 0.000230333
# G_tau measure         | 0.00144026
# Total measure time    | 0.00301191
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.131567
#   Move  Insert Delta_up: 0.133715
#   Move  Insert Delta_down: 0.129426
# Move set Remove two operators: 0.130663
#   Move  Remove Delta_up: 0.13311
#   Move  Remove Delta_dow
#
# Iteration = 6 / 10
# n: 0.128214
# Move set Insert four operators: 0.0276007
#   Move  Insert Delta_up_up: 0.0306565
#   Move  Insert Delta_up_down: 0.0254948
#   Move  Insert Delta_down_up: 0.025725
#   Move  Insert Delta_down_down: 0.0285063
# Move set Remove four operators: 0.0284674
#   Move  Remove Delta_up_up: 0.0316303
#   Move  Remove Delta_up_down: 0.0252882
#   Move  Remove Delta_down_up: 0.0267753
#   Move  Remove Delta_down_down: 0.0301962
# Move  Shift one operator: 0.677651
# [Rank 0] Warmup lasted: 0.293382 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.58853 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.2701
# Auto-correlation time: 2.43454
# Iteration = 7 / 10
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
#
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:24  34% ETA 00:00:00 cycle 1710 of 5000
# 22:15:24 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:24  16% ETA 00:00:00 cycle 1689 of 10000
# 22:15:24 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00109014
# Average order         | 0.000229832
# Average sign          | 0.000235149
# G_tau measure         | 0.00207921
# Total measure time    | 0.00363434
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.127818
#   Move  Insert Delta_up: 0.127863
#   Move  Insert Delta_down: 0.127773
# Move set Remove two operators: 0.128597
#   Move  Remove Delta_up: 0.128824
#   Move  Remove Delta_down: 0.12837
# Move set Insert four operators: 0.0270821
#   Move  Insert Delta_up_up: 0.0302706
#   Move  Insert Delta_up_down: 0.0244285
#   Move  Insert Delta_down_up: 0.0250341
#   Move  Insert Delta_down_down: 0.0285486
# Move set Remove four operators: 0.0268681
#   Move  Remove Delta_up_up: 0.029369
#   Move  Remove Delta_up_down: 0.0251997
#   Move  Remove Delta_down_up: 0.0249889
#   Move  Remove Delta_down_down: 0.0279296
# Move  Shift one operator: 0.680676
# [Rank 0] Warmup lasted: 0.293675 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.593945 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.4495
# Auto-correlation time: 4.93486
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
#
#
# Iteration = 8 / 10
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:25  33% ETA 00:00:00 cycle 1682 of 5000
# 22:15:25 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:25  15% ETA 00:00:00 cycle 1537 of 10000
# 22:15:25 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00118122
# Average order         | 0.000265631
# Average sign          | 0.000242118
# G_tau measure         | 0.00303887
# Total measure time    | 0.00472784
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.128634
#   Move  Insert Delta_up: 0.128384
#   Move  Insert Delta_down: 0.128883
# Move set Remove two operators: 0.129022
#   Move  Remove Delta_up: 0.12886
#   Move  Remove Delta_down: 0.129184
# Move set Insert four operators: 0.0264743
#   Move  Insert Delta_up_up: 0.0287922
#   Move  Insert Delta_up_down: 0.0235365
#   Move  Insert Delta_down_up: 0.0237667
#   Move  Insert Delta_down_down: 0.0297869
# Move set Remove four operators: 0.026674
#   Move  Remove Delta_up_up: 0.0276172
#   Move  Remove Delta_up_down: 0.0253356
#   Move  Remove Delta_down_up: 0.0249358
#   Move  Remove Delta_down_down: 0.0288193
# Move  Shift one operator: 0.681544
# [Rank 0] Warmup lasted: 0.295738 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.628498 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.4043
# Auto-correlation time: 2.96938
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:26  34% ETA 00:00:00 cycle 1704 of 5000
# 22:15:26 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:26  17% ETA 00:00:00 cycle 1710 of 10000
# 22:15:26 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00107784
# Average order         | 0.000229151
# Average sign          | 0.000235165
# G_tau measure         | 0.00147502
# Total measure time    | 0.00301717
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.132223
#   Move  Insert Delta_up: 0.132401
#   Move  Insert Delta_down: 0.132044
# Move set Remove two operators: 0.129861
#   Move  Remove Delta_up: 0.12952
#   Move  Remove Delta_dow
#
# Iteration = 9 / 10
# n: 0.130201
# Move set Insert four operators: 0.0269862
#   Move  Insert Delta_up_up: 0.0305089
#   Move  Insert Delta_up_down: 0.0243726
#   Move  Insert Delta_down_up: 0.0237724
#   Move  Insert Delta_down_down: 0.0292517
# Move set Remove four operators: 0.0282147
#   Move  Remove Delta_up_up: 0.0309872
#   Move  Remove Delta_up_down: 0.0276375
#   Move  Remove Delta_down_up: 0.0263264
#   Move  Remove Delta_down_down: 0.0279213
# Move  Shift one operator: 0.677678
# [Rank 0] Warmup lasted: 0.293373 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.587853 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.242
# Auto-correlation time: 2.74536
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
#
#
# Iteration = 10 / 10
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:26  34% ETA 00:00:00 cycle 1708 of 5000
# 22:15:27 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:27  17% ETA 00:00:00 cycle 1706 of 10000
# 22:15:27 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.0010882
# Average order         | 0.000233093
# Average sign          | 0.000236796
# G_tau measure         | 0.0014274
# Total measure time    | 0.00298549
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.130937
#   Move  Insert Delta_up: 0.132246
#   Move  Insert Delta_down: 0.12963
# Move set Remove two operators: 0.131236
#   Move  Remove Delta_up: 0.132046
#   Move  Remove Delta_down: 0.130424
# Move set Insert four operators: 0.0276569
#   Move  Insert Delta_up_up: 0.0298347
#   Move  Insert Delta_up_down: 0.0258974
#   Move  Insert Delta_down_up: 0.0245561
#   Move  Insert Delta_down_down: 0.0303272
# Move set Remove four operators: 0.0277909
#   Move  Remove Delta_up_up: 0.0306308
#   Move  Remove Delta_up_down: 0.0249253
#   Move  Remove Delta_down_up: 0.0255935
#   Move  Remove Delta_down_down: 0.0300287
# Move  Shift one operator: 0.675164
# [Rank 0] Warmup lasted: 0.292311 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.586217 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.2563
# Auto-correlation time: 4.01083
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# U = 3.0
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:27  33% ETA 00:00:00 cycle 1693 of 5000
# 22:15:28 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:28  16% ETA 00:00:00 cycle 1696 of 10000
# 22:15:28 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00110974
# Average order         | 0.000231459
# Average sign          | 0.000234321
# G_tau measure         | 0.00237515
# Total measure time    | 0.00395067
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.131003
#   Move  Insert Delta_up: 0.131509
#   Move  Insert Delta_down: 0.1305
# Move set Remove two operators: 0.130783
#   Move  Remove Delta_up: 0.130729
#   Move  Remove Delta_down: 0.130837
# Move set Insert four operators: 0.0263867
#   Move  Insert Delta_up_up: 0.0290737
#   Move  Insert Delta_up_down: 0.0231511
#   Move  Insert Delta_down_up: 0.0250389
#   Move  Insert Delta_down_down: 0.0282522
# Move set Remove four operators: 0.0267621
#   Move  Remove Delta_up_up: 0.0297348
#   Move  Remove Delta_up_down: 0.0242209
#   Move  Remove Delta_down_up: 0.0247709
#   Move  Remove Delta_down_down: 0.0283461
# Move  Shift one operator: 0.67701
# [Rank 0] Warmup lasted: 0.292678 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.59083 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.3268
# Auto-correlation time: 0.794236
#
#
# Iteration = 1 / 10
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1.5*c_dag('down',0)*c('down',0) + -1.5*c_dag('up',0)*c('up',0) + 3*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:28  37% ETA 00:00:00 cycle 1849 of 5000
# 22:15:28 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:29  18% ETA 00:00:00 cycle 1840 of 10000
# 22:15:29 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.0011249
# Average order         | 0.000232769
# Average sign          | 0.000236596
# G_tau measure         | 0.00190066
# Total measure time    | 0.00349493
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.112247
#   Move  Insert Delta_up: 0.113798
#   Move  Insert Delta_down: 0.110696
# Move set Remove two operators: 0.111523
#   Move  Remove Delta_up: 0.11241
#   Move  Remove Delta
#
# Iteration = 2 / 10
# _down: 0.110636
# Move set Insert four operators: 0.0226176
#   Move  Insert Delta_up_up: 0.0237627
#   Move  Insert Delta_up_down: 0.0205814
#   Move  Insert Delta_down_up: 0.0218449
#   Move  Insert Delta_down_down: 0.0242896
# Move set Remove four operators: 0.0232029
#   Move  Remove Delta_up_up: 0.0245147
#   Move  Remove Delta_up_down: 0.022101
#   Move  Remove Delta_down_up: 0.0226071
#   Move  Remove Delta_down_down: 0.0235938
# Move  Shift one operator: 0.568929
# [Rank 0] Warmup lasted: 0.269949 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.542302 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.0545
# Auto-correlation time: 2.35299
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1.5*c_dag('down',0)*c('down',0) + -1.5*c_dag('up',0)*c('up',0) + 3*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:29  39% ETA 00:00:00 cycle 1991 of 5000
# 22:15:29 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:29  19% ETA 00:00:00 cycle 1965 of 10000
# 22:15:30 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00109687
# Average order         | 0.00023452
# Average sign          | 0.000238864
# G_tau measure         | 0.00140049
# Total measure time    | 0.00297074
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.119575
#   Move  Insert Delta_up: 0.118774
#   Move  Insert Delta_down: 0.120375
# Move set Remove two operators: 0.118525
#   Move  Remove Delta_up: 0.117625
#   Move  Remove Delta
#
# Iteration = 3 / 10
# _down: 0.119424
# Move set Insert four operators: 0.0260688
#   Move  Insert Delta_up_up: 0.0249124
#   Move  Insert Delta_up_down: 0.0259468
#   Move  Insert Delta_down_up: 0.028224
#   Move  Insert Delta_down_down: 0.0251899
# Move set Remove four operators: 0.0267536
#   Move  Remove Delta_up_up: 0.026036
#   Move  Remove Delta_up_down: 0.0281528
#   Move  Remove Delta_down_up: 0.0270466
#   Move  Remove Delta_down_down: 0.0257593
# Move  Shift one operator: 0.509178
# [Rank 0] Warmup lasted: 0.249505 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.507644 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 6.1244
# Auto-correlation time: 3.95588
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1.5*c_dag('down',0)*c('down',0) + -1.5*c_dag('up',0)*c('up',0) + 3*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:30  39% ETA 00:00:00 cycle 1984 of 5000
# 22:15:30 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:30  19% ETA 00:00:00 cycle 1984 of 10000
# 22:15:31 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00109319
# Average order         | 0.000230504
# Average sign          | 0.000231776
# G_tau measure         | 0.0013651
# Total measure time    | 0.00292056
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.116787
#   Move  Insert Delta_up: 0.116187
#   Move  Insert Delta_down: 0.117384
# Move set Remove two operators: 0.116633
#   Move  Remove Delta_up: 0.116475
#   Move  Remove Delta_down: 0.11679
# Move set Insert four operators: 0.0259455
#   Move  Insert Delta_up_up: 0.026201
#   Move  Insert Delta_up_down: 0.0258814
#   Move  Insert Delta_down_up: 0.0264806
#   Move  Insert Delta_down_down: 0.0252178
# Move set Remove four operators: 0.0264393
#   Move  Remove Delta_up_up: 0.0269715
#   Move  Remove Delta_up_down: 0.0248916
#   Move  Remove Delta_down_up: 0.026979
#   Move  Remove Delta_down_down: 0.0269331
# Move  Shift one operator: 0.520079
# [Rank 0] Warmup lasted: 0.25403 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.513273 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 6.2308
# Auto-correlation time: 5.61951
#
#
# Iteration = 4 / 10
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1.5*c_dag('down',0)*c('down',0) + -1.5*c_dag('up',0)*c('up',0) + 3*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:31  39% ETA 00:00:00 cycle 1951 of 5000
# 22:15:31 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:31  19% ETA 00:00:00 cycle 1972 of 10000
# 22:15:31 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.0010926
# Average order         | 0.000229515
# Average sign          | 0.000233109
# G_tau measure         | 0.00134761
# Total measure time    | 0.00290283
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.119259
#   Move  Insert Delta_up: 0.118998
#   Move  Insert Delta_down: 0.11952
# Move set Remove two operators: 0.11786
#   Move  Remove Delta_up: 0.11722
#   Move  Remove Delta_down: 0.118509
# Move set Insert four operators: 0.0262007
#   Move  Insert Delta_up_up: 0.0247214
#   Move  Insert Delta_up_down: 0.0280183
#   Move  Insert Delta_down_up: 0.0277204
#   Move  Insert Delta_down_down: 0.0243335
# Move set Remove four operators: 0.0270037
#   Move  Remove Delta_up_up: 0.0264473
#   Move  Remove Delta_up_down: 0.0269378
#   Move  Remove Delta_down_up: 0.0272082
#   Move  Remove Delta_down_down: 0.027421
# Move  Shift one operator: 0.514142
# [Rank 0] Warmup lasted: 0.252776 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.507985 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 6.1344
# Auto-correlation time: 5.42356
#
#
# Iteration = 5 / 10
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
#
#
# Iteration = 6 / 10
# -1.5*c_dag('down',0)*c('down',0) + -1.5*c_dag('up',0)*c('up',0) + 3*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:32  39% ETA 00:00:00 cycle 1980 of 5000
# 22:15:32 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:32  19% ETA 00:00:00 cycle 1932 of 10000
# 22:15:32 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00107668
# Average order         | 0.000225497
# Average sign          | 0.000234349
# G_tau measure         | 0.00127644
# Total measure time    | 0.00281297
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.12076
#   Move  Insert Delta_up: 0.121218
#   Move  Insert Delta_down: 0.120303
# Move set Remove two operators: 0.121201
#   Move  Remove Delta_up: 0.121831
#   Move  Remove Delta_down: 0.120573
# Move set Insert four operators: 0.0267368
#   Move  Insert Delta_up_up: 0.026411
#   Move  Insert Delta_up_down: 0.0274809
#   Move  Insert Delta_down_up: 0.0270616
#   Move  Insert Delta_down_down: 0.0260013
# Move set Remove four operators: 0.0265407
#   Move  Remove Delta_up_up: 0.025342
#   Move  Remove Delta_up_down: 0.0281685
#   Move  Remove Delta_down_up: 0.0271009
#   Move  Remove Delta_down_down: 0.0255323
# Move  Shift one operator: 0.515457
# [Rank 0] Warmup lasted: 0.252216 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.50991 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 6.1383
# Auto-correlation time: 3.12987
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1.5*c_dag('down',0)*c('down
#
# Iteration = 7 / 10
# ',0) + -1.5*c_dag('up',0)*c('up',0) + 3*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:32  39% ETA 00:00:00 cycle 1976 of 5000
# 22:15:32 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:33  19% ETA 00:00:00 cycle 1984 of 10000
# 22:15:33 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00109437
# Average order         | 0.0002309
# Average sign          | 0.00023704
# G_tau measure         | 0.00144865
# Total measure time    | 0.00301095
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.117368
#   Move  Insert Delta_up: 0.117308
#   Move  Insert Delta_down: 0.117427
# Move set Remove two operators: 0.117241
#   Move  Remove Delta_up: 0.116591
#   Move  Remove Delta_down: 0.117894
# Move set Insert four operators: 0.0261457
#   Move  Insert Delta_up_up: 0.0261487
#   Move  Insert Delta_up_down: 0.0253525
#   Move  Insert Delta_down_up: 0.0266688
#   Move  Insert Delta_down_down: 0.0264136
# Move set Remove four operators: 0.0265045
#   Move  Remove Delta_up_up: 0.0252665
#   Move  Remove Delta_up_down: 0.0275678
#   Move  Remove Delta_down_up: 0.0282901
# ...
# Accumulating ...
# 22:15:56  50% ETA 00:00:00 cycle 5005 of 10000
# 22:15:56 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00111846
# Average order         | 0.000240757
# Average sign          | 0.000231423
# G_tau measure         | 0.000874775
# Total measure time    | 0.00246541
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.0766449
#   Move  Insert Delta_up: 0.0764292
#   Move  Insert Delta_down: 0.0768612
# Move set Remove two operators: 0.0761625
#   Move  Remove Delta_up: 0.0763946
#   Move  Remove Delta_down: 0.0759317
# Move set Insert four operators: 0.0106741
#   Move  Insert Delta_up_up: 0.00774466
#   Move  Insert Delta_up_down: 0.0136975
#   Move  Insert Delta_down_up: 0.0145652
#   Move  Insert Delta_down_down: 0.0067659
# Move set Remove four operators: 0.0108867
#   Move  Remove Delta_up_up: 0.00786259
#   Move  Remove Delta_up_down: 0.0137408
#   Move  Remove Delta_down_up: 0.0148857
#   Move  Remove Delta_down_down: 0.00699944
# Move  Shift one operator: 0.0664264
# [Rank 0] Warmup lasted: 0.0992103 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.199665 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 1.4098
# Auto-correlation time: 1.66327
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -4*c_dag('down',0)*c('down',0) + -4*c_dag('up',0)*c('up',0) + 8*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:56 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:56  53% ETA 00:00:00 cycle 5379 of 10000
# 22:15:56 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00114135
# Average order         | 0.000225261
# Average sign          | 0.000228582
# G_tau measure         | 0.000713804
# Total measure time    | 0.002309
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.0666085
#   Move  Insert Delta_up: 0.0665451
#   Move  Insert Delta_down: 0.066672
# Move set Remove two operators: 0.0667213
#   Move  Remove Delta_up: 0.0672132
#   Move  Remove Delta_down: 0.0662322
# Move set Insert four operators: 0.00669763
#   Move  Insert Delta_up_up: 0.00602932
#   Move  Insert Delta_up_down: 0.00748431
#   Move  Insert Delta_down_up: 0.00769875
#   Move  Insert Delta_down_down: 0.00559172
# Move set Remove four operators: 0.00652602
#   Move  Remove Delta_up_up: 0.00578662
#   Move  Remove Delta_up_down: 0.00698408
#   Move  Remove Delta_down_up: 0.00760865
#   Move  Remove Delta_down_down: 0.00571634
# Move  Shift one operator: 0.0514166
# [Rank 0] Warmup lasted: 0.0912396 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.184387 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 0.9996
# Average order: 1.2625
# Auto-correlation time: 1.92343
#
#
# Iteration = 4 / 10
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
#
#
# Iteration = 5 / 10
# -4*c_dag('down',0)*c('down',0) + -4*c_dag('up',0)*c('up',0) + 8*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:56 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:56  53% ETA 00:00:00 cycle 5386 of 10000
# 22:15:56 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00114802
# Average order         | 0.000221955
# Average sign          | 0.00022814
# G_tau measure         | 0.00067304
# Total measure time    | 0.00227115
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.0648141
#   Move  Insert Delta_up: 0.0634921
#   Move  Insert Delta_down: 0.0661443
# Move set Remove two operators: 0.0649517
#   Move  Remove Delta_up: 0.0649518
#   Move  Remove Delta_down: 0.0649516
# Move set Insert four operators: 0.0061691
#   Move  Insert Delta_up_up: 0.00587146
#   Move  Insert Delta_up_down: 0.00646862
#   Move  Insert Delta_down_up: 0.00744427
#   Move  Insert Delta_down_down: 0.00489611
# Move set Remove four operators: 0.00601018
#   Move  Remove Delta_up_up: 0.00491658
#   Move  Remove Delta_up_down: 0.00690701
#   Move  Remove Delta_down_up: 0.00676294
#   Move  Remove Delta_down_down: 0.00544022
# Move  Shift one operator: 0.0503358
# [Rank 0] Warmup lasted: 0.0916004 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.183801 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 0.9972
# Average order: 1.2763
# Auto-correlation time: 2.76404
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -4*c_dag('down',0)*c('down',0) + -4*c_dag('up',0)*c('up',0) + 8*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
#
#
# Iteration = 6 / 10
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:56 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:57  53% ETA 00:00:00 cycle 5363 of 10000
# 22:15:57 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00115811
# Average order         | 0.000227656
# Average sign          | 0.000229708
# G_tau measure         | 0.000704216
# Total measure time    | 0.00231969
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.0649176
#   Move  Insert Delta_up: 0.0641392
#   Move  Insert Delta_down: 0.0657014
# Move set Remove two operators: 0.0647029
#   Move  Remove Delta_up: 0.0646974
#   Move  Remove Delta_down: 0.0647083
# Move set Insert four operators: 0.00594983
#   Move  Insert Delta_up_up: 0.00583274
#   Move  Insert Delta_up_down: 0.00662917
#   Move  Insert Delta_down_up: 0.00637781
#   Move  Insert Delta_down_down: 0.00496899
# Move set Remove four operators: 0.00605891
#   Move  Remove Delta_up_up: 0.00579733
#   Move  Remove Delta_up_down: 0.00580425
#   Move  Remove Delta_down_up: 0.00740682
#   Move  Remove Delta_down_down: 0.00521816
# Move  Shift one operator: 0.0500971
# [Rank 0] Warmup lasted: 0.0925798 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.184646 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 0.9928
# Average order: 1.2804
# Auto-correlation time: 1.52751
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -4*c_dag('down',0)*c('down',0) + -4*c_dag('up',0)*c('up',0) + 8*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:57 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:57  53% ETA 00:00:00 cycle 5311 of 10000
# 22:15:57 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00116097
# Average order         | 0.000227386
# Average sign          | 0.000231975
# G_tau measure         | 0.000861263
# Total measure time    | 0.00248159
# [Rank 0] Accepta
#
# Iteration = 7 / 10
# nce rate for all moves:
# Move set Insert two operators: 0.0648434
#   Move  Insert Delta_up: 0.0639435
#   Move  Insert Delta_down: 0.0657487
# Move set Remove two operators: 0.0652002
#   Move  Remove Delta_up: 0.0650621
#   Move  Remove Delta_down: 0.0653372
# Move set Insert four operators: 0.00653185
#   Move  Insert Delta_up_up: 0.00647684
#   Move  Insert Delta_up_down: 0.00700224
#   Move  Insert Delta_down_up: 0.00712778
#   Move  Insert Delta_down_down: 0.00552508
# Move set Remove four operators: 0.00633317
#   Move  Remove Delta_up_up: 0.00574294
#   Move  Remove Delta_up_down: 0.00628081
#   Move  Remove Delta_down_up: 0.00798945
#   Move  Remove Delta_down_down: 0.00531256
# Move  Shift one operator: 0.0519887
# [Rank 0] Warmup lasted: 0.0918102 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.18518 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 0.9896
# Average order: 1.2736
# Auto-correlation time: 2.97512
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -4*c_dag('down',0)*c('down',0) + -4*c_dag('up',0)*c('up',0) + 8*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:57 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:57  53% ETA 00:00:00 cycle 5372 of 10000
# 22:15:57 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00116237
# Average order         | 0.000225235
# Average sign          | 0.000227887
# G_tau measure         | 0.000646706
# Total measure time    | 0.0022622
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.0651064
#   Move  Insert Delta_up: 0.0640138
#   Move  Insert Delta_down: 0.0661968
# Move set Remove two operators: 0.064921
#   Move  Remove Delta_up: 0.0643386
#   Move  Remove Delta_down: 0.0655007
# Move set Insert four operators: 0.00608775
#   Move  Insert Delta_up_up: 0.00550639
#   Move  Insert Delta_up_down: 0.00688303
#   Move  Insert Delta_down_up: 0.00702353
#   Move  Insert Delta_down_down: 0.00494438
# Move set Remove four operators: 0.00612031
#   Move  Remove Delta_up_up: 0.00518802
#   Move  Remove Delta_up_down: 0.006465
#   Move  Remove Delta_down_up: 0.00749811
#   Move  Remove Delta_down_down: 0.00532021
# Move  Shift one operator: 0.0501661
# [Rank 0] Warmup lasted: 0.0927823 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.183472 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 0.9908
# Average order: 1.2712
# Auto-correlation time: 2.45363
#
#
# Iteration = 8 / 10
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -4*c_dag('down',0)*c('down',0) + -4*c_dag('up',0)*c('up',0) + 8*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
#
#
# Iteration = 9 / 10
# Found 4 subspaces.
#
# Warming up ...
# 22:15:57 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:58  53% ETA 00:00:00 cycle 5356 of 10000
# 22:15:58 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00114233
# Average order         | 0.000222417
# Average sign          | 0.000228306
# G_tau measure         | 0.000657173
# Total measure time    | 0.00225023
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.0650171
#   Move  Insert Delta_up: 0.0644201
#   Move  Insert Delta_down: 0.0656194
# Move set Remove two operators: 0.0655976
#   Move  Remove Delta_up: 0.0658945
#   Move  Remove Delta_down: 0.0653032
# Move set Insert four operators: 0.00591916
#   Move  Insert Delta_up_up: 0.00558637
#   Move  Insert Delta_up_down: 0.00615606
#   Move  Insert Delta_down_up: 0.00691088
#   Move  Insert Delta_down_down: 0.00502934
# Move set Remove four operators: 0.0055814
#   Move  Remove Delta_up_up: 0.00478277
#   Move  Remove Delta_up_down: 0.00636994
#   Move  Remove Delta_down_up: 0.00639437
#   Move  Remove Delta_down_down: 0.00477878
# Move  Shift one operator: 0.0504766
# [Rank 0] Warmup lasted: 0.0897256 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.184324 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 0.9974
# Average order: 1.2853
# Auto-correlation time: 2.65569
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -4*c_dag('down',0)*c('down',0) + -4*c_dag('up',0)*c('up',0) + 8*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
#
#
# Iteration = 10 / 10
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:58 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:58  52% ETA 00:00:00 cycle 5285 of 10000
# 22:15:58 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00115325
# Average order         | 0.000232611
# Average sign          | 0.00022953
# G_tau measure         | 0.000762409
# Total measure time    | 0.0023778
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.06511
#   Move  Insert Delta_up: 0.0645775
#   Move  Insert Delta_down: 0.0656442
# Move set Remove two operators: 0.065331
#   Move  Remove Delta_up: 0.0647873
#   Move  Remove Delta_down: 0.0658719
# Move set Insert four operators: 0.00569673
#   Move  Insert Delta_up_up: 0.00567891
#   Move  Insert Delta_up_down: 0.00563549
#   Move  Insert Delta_down_up: 0.00576908
#   Move  Insert Delta_down_down: 0.00570335
# Move set Remove four operators: 0.0056422
#   Move  Remove Delta_up_up: 0.00595789
#   Move  Remove Delta_up_down: 0.00547803
#   Move  Remove Delta_down_up: 0.00585611
#   Move  Remove Delta_down_down: 0.0052781
# Move  Shift one operator: 0.0523878
# [Rank 0] Warmup lasted: 0.0928731 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.18596 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 0.9978
# Average order: 1.3104
# Auto-correlation time: 2.14769
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -4*c_dag('down',0)*c('down',0) + -4*c_dag('up',0)*c('up',0) + 8*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:58 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:58  54% ETA 00:00:00 cycle 5402 of 10000
# 22:15:58 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00114802
# Average order         | 0.000233195
# Average sign          | 0.000227849
# G_tau measure         | 0.000716898
# Total measure time    | 0.00232596
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.0655441
#   Move  Insert Delta_up: 0.0641989
#   Move  Insert Delta_down: 0.066902
# Move set Remove two operators: 0.0656663
#   Move  Remove Delta_up: 0.0655177
#   Move  Remove Delta_down: 0.065813
# Move set Insert four operato
# rs: 0.00574329
#   Move  Insert Delta_up_up: 0.00615239
#   Move  Insert Delta_up_down: 0.00584514
#   Move  Insert Delta_down_up: 0.00617653
#   Move  Insert Delta_down_down: 0.0047931
# Move set Remove four operators: 0.00557688
#   Move  Remove Delta_up_up: 0.00536355
#   Move  Remove Delta_up_down: 0.00589547
#   Move  Remove Delta_down_up: 0.0062092
#   Move  Remove Delta_down_down: 0.00483401
# Move  Shift one operator: 0.0511499
# [Rank 0] Warmup lasted: 0.0912338 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.184074 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 0.9968
# Average order: 1.2817
# Auto-correlation time: 2.92277

# %% [markdown]
# The script saves the Green's functions and self-energies in archives in the subdirectory called `results`. They will be used for the analysis below. We study several values of $U$ to see how the Green's functions will change. Note that these runs takes a bit of time!
#
# You can
#
# - run this directly from the shell to see the Monte Carlo progress or
# - run the command below.

# %%
# %run scripts/one_band.py
# Out:
# U = 1.0
#
#
# Iteration = 1 / 10
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -0.5*c_dag('down',0)*c('down',0) + -0.5*c_dag('up',0)*c('up',0) + 1*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:58  30% ETA 00:00:00 cycle 1542 of 5000
# 22:15:59 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:15:59  15% ETA 00:00:00 cycle 1535 of 10000
# 22:15:59 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00107119
# Average order         | 0.00023295
# Average sign          | 0.0002368
# G_tau measure         | 0.00196401
# Total measure time    | 0.00350494
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.134194
#   Move  Insert Delta_up: 0.135137
#   Move  Insert Delta_down: 0.133256
# Move set Remove two operators: 0.134078
#   Move  Remove Delta_up: 0.134495
#   Move  Remove Delta_
#
# Iteration = 2 / 10
# down: 0.13366
# Move set Insert four operators: 0.0237206
#   Move  Insert Delta_up_up: 0.0263818
#   Move  Insert Delta_up_down: 0.0215067
#   Move  Insert Delta_down_up: 0.0192815
#   Move  Insert Delta_down_down: 0.0276912
# Move set Remove four operators: 0.0240728
#   Move  Remove Delta_up_up: 0.027297
#   Move  Remove Delta_up_down: 0.0201105
#   Move  Remove Delta_down_up: 0.0206622
#   Move  Remove Delta_down_down: 0.0282551
# Move  Shift one operator: 0.83864
# [Rank 0] Warmup lasted: 0.32404 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.652896 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 8.1807
# Auto-correlation time: 3.07816
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -0.5*c_dag('down',0)*c('down',0) + -0.5*c_dag('up',0)*c('up',0) + 1*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:15:59  31% ETA 00:00:00 cycle 1568 of 5000
# 22:16:00 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:00  15% ETA 00:00:00 cycle 1556 of 10000
# 22:16:00 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00112698
# Average order         | 0.000228427
# Average sign          | 0.000232989
# G_tau measure         | 0.00200302
# To
# tal measure time    | 0.00359142
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.137529
#   Move  Insert Delta_up: 0.138608
#   Move  Insert Delta_down: 0.136454
# Move set Remove two operators: 0.135646
#   Move  Remove Delta_up: 0.137095
#   Move  Remove Delta_down: 0.134192
# Move set Insert four operators: 0.0248063
#   Move  Insert Delta_up_up: 0.029023
#   Move  Insert Delta_up_down: 0.0202982
#   Move  Insert Delta_down_up: 0.0212102
#   Move  Insert Delta_down_down: 0.0286456
# Move set Remove four operators: 0.0258106
#   Move  Remove Delta_up_up: 0.0300133
#   Move  Remove Delta_up_down: 0.0207927
#   Move  Remove Delta_down_up: 0.0216027
#   Move  Remove Delta_down_down: 0.0308751
# Move  Shift one operator: 0.82967
# [Rank 0] Warmup lasted: 0.321066 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.650166 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 8.0726
# Auto-correlation time: 2.95457
#
#
# Iteration = 3 / 10
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -0.5*c_dag('down',0)*c('down',0) + -0.5*c_dag('up',0)*c('up',0) + 1*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:00  30% ETA 00:00:00 cycle 1539 of 5000
# 22:16:01 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:01  15% ETA 00:00:00 cycle 1536 of 10000
# 22:16:01 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00111352
# Average order         | 0.000229201
# Average sign          | 0.000232592
# G_tau measure         | 0.00253445
# Total measure time    | 0.00410976
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.136691
#   Move  Insert Delta_up: 0.136118
#   Move  Insert Delta_down: 0.137262
# Move set Remove two operators: 0.135948
#   Move  Remove Delta_up: 0.135115
#   Move  Remove Delta_down: 0.136781
# Move set Insert four operators: 0.024431
#   Move  Insert Delta_up_up: 0.0279642
#   Move  Insert Delta_up_
#
# Iteration = 4 / 10
# down: 0.0212578
#   Move  Insert Delta_down_up: 0.021372
#   Move  Insert Delta_down_down: 0.0270992
# Move set Remove four operators: 0.0251374
#   Move  Remove Delta_up_up: 0.0298838
#   Move  Remove Delta_up_down: 0.0205143
#   Move  Remove Delta_down_up: 0.0209849
#   Move  Remove Delta_down_down: 0.0291752
# Move  Shift one operator: 0.832854
# [Rank 0] Warmup lasted: 0.322553 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.653046 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 8.1617
# Auto-correlation time: 1.88829
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -0.5*c_dag('down',0)*c('down',0) + -0.5*c_dag('up',0)*c('up',0) + 1*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:01  31% ETA 00:00:00 cycle 1563 of 5000
# 22:16:02 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:02  15% ETA 00:00:00 cycle 1551 of 10000
# 22:16:02 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00112331
# Average order         | 0.000228247
# Average sign          | 0.000240345
# G_tau measure         | 0.00207058
# Total measure time    | 0.00366248
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.137877
#   Move  Insert Delta_up: 0.13878
#   Move  Insert Delta_down: 0.136976
# Move set Remove two operators: 0.136859
#   Move  Remove Delta_up: 0.137844
#   Move  Remove Delta_down: 0.135872
# Move set Insert four operators: 0.0240401
#   Move  Insert Delta_up_up: 0.0279466
#   Move  Insert Delta_up_
#
# Iteration = 5 / 10
# down: 0.0193165
#   Move  Insert Delta_down_up: 0.0205293
#   Move  Insert Delta_down_down: 0.0283427
# Move set Remove four operators: 0.0247222
#   Move  Remove Delta_up_up: 0.0272073
#   Move  Remove Delta_up_down: 0.0219802
#   Move  Remove Delta_down_up: 0.0218302
#   Move  Remove Delta_down_down: 0.0278651
# Move  Shift one operator: 0.830322
# [Rank 0] Warmup lasted: 0.321375 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.65242 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 8.1484
# Auto-correlation time: 1.59076
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -0.5*c_dag('down',0)*c('down',0) + -0.5*c_dag('up',0)*c('up',0) + 1*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:02  30% ETA 00:00:00 cycle 1545 of 5000
# 22:16:03 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:03  15% ETA 00:00:00 cycle 1531 of 10000
# 22:16:03 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00109512
# Average order         | 0.000231537
# Average sign          | 0.000238049
# G_tau measure         | 0.00172307
# Total measure time    | 0.00328777
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.136129
#   Move  Insert Delta_up: 0.135304
#   Move  Insert Delta_down: 0.136951
# Move set Remove two operators: 0.137127
#   Move  Remove Delta_up: 0.1367
#   Move  Remove Delta_
#
# Iteration = 6 / 10
# down: 0.137554
# Move set Insert four operators: 0.024601
#   Move  Insert Delta_up_up: 0.0281926
#   Move  Insert Delta_up_down: 0.0207839
#   Move  Insert Delta_down_up: 0.0216895
#   Move  Insert Delta_down_down: 0.027688
# Move set Remove four operators: 0.0242563
#   Move  Remove Delta_up_up: 0.0271906
#   Move  Remove Delta_up_down: 0.0216098
#   Move  Remove Delta_down_up: 0.0202847
#   Move  Remove Delta_down_down: 0.0279555
# Move  Shift one operator: 0.830414
# [Rank 0] Warmup lasted: 0.32291 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.652259 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 8.1626
# Auto-correlation time: 2.51126
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -0.5*c_dag('down',0)*c('down',0) + -0.5*c_dag('up',0)*c('up',0) + 1*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:03  30% ETA 00:00:00 cycle 1543 of 5000
# 22:16:04 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:04  15% ETA 00:00:00 cycle 1553 of 10000
# 22:16:04 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00110641
# Average order         | 0.000231723
# Average sign          | 0.000234396
# G_tau measure         | 0.00166239
# Total measure time    | 0.00323492
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.136631
#   Move  Insert Delta_up: 0.137952
#   Move  Insert Delta_down: 0.135314
# Move set Remove two operators: 0.138106
#   Move  Remove Delta_up: 0.13836
#   Move  Remove Delta_down: 0.137851
# Move set Insert four operators: 0.0257115
#   Move  Insert Delta_up_up: 0.029352
#   Move  Insert Delta_up_down: 0.0212757
#   Move  Insert Delta_down_up: 0.0216313
#   Move  Insert Delta_down_down: 0.030564
# Move set Remove four operators: 0.0249482
#   Move  Remove Delta_up_up: 0.0290644
#   Move  Remove Delta_up_down: 0.0214022
#   Move  Remove Delta_down_up: 0.0207806
#   Move  Remove Delta_down_down: 0.0285886
# Move  Shift one operator: 0.830217
# [Rank 0] Warmup lasted: 0.322235 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.651915 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 8.1595
# Auto-correlation time: 3.00369
#
#
# Iteration = 7 / 10
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -0.5*c_dag('down',0)*c('down',0) + -0.5*c_dag('up',0)*c('up',0) + 1*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:04  31% ETA 00:00:00 cycle 1549 of 5000
# 22:16:05 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:05  15% ETA 00:00:00 cycle 1573 of 10000
# 22:16:05 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00112168
# Average order         | 0.000231849
# Average sign          | 0.000232432
# G_tau measure         | 0.0019686
# Total measure time    | 0.00355457
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.138683
#   Move  Insert Delta_up: 0.138785
#   Move  Insert Delta_down: 0.138581
# Move set Remove two operators: 0.135491
#   Move  Remove Delta_up: 0.134835
#   Move  Remove Delt
#
# Iteration = 8 / 10
# a_down: 0.136151
# Move set Insert four operators: 0.0238837
#   Move  Insert Delta_up_up: 0.0282195
#   Move  Insert Delta_up_down: 0.0187678
#   Move  Insert Delta_down_up: 0.0213364
#   Move  Insert Delta_down_down: 0.0271656
# Move set Remove four operators: 0.0256944
#   Move  Remove Delta_up_up: 0.0296998
#   Move  Remove Delta_up_down: 0.0223175
#   Move  Remove Delta_down_up: 0.0230494
#   Move  Remove Delta_down_down: 0.0277512
# Move  Shift one operator: 0.826742
# [Rank 0] Warmup lasted: 0.323024 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.647914 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 8.0322
# Auto-correlation time: 3.10339
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -0.5*c_dag('down',0)*c('down',0) + -0.5*c_dag('up',0)*c('up',0) + 1*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:05  31% ETA 00:00:00 cycle 1552 of 5000
# 22:16:06 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:06  15% ETA 00:00:00 cycle 1538 of 10000
# 22:16:06 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00106067
# Average order         | 0.000231317
# Average sign          | 0.000234164
# G_tau measure         | 0.00162969
# Total measure time    | 0.00315585
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.138506
#   Move  Insert Delta_up: 0.139623
#   Move  Insert Delta_down: 0.137394
# Move set Remove two operators: 0.138454
#   Move  Remove Delta_up: 0.136949
#   Move  Remove Delt
#
# Iteration = 9 / 10
# a_down: 0.139969
# Move set Insert four operators: 0.0253769
#   Move  Insert Delta_up_up: 0.0293179
#   Move  Insert Delta_up_down: 0.0211004
#   Move  Insert Delta_down_up: 0.0205091
#   Move  Insert Delta_down_down: 0.0305689
# Move set Remove four operators: 0.0253767
#   Move  Remove Delta_up_up: 0.0309133
#   Move  Remove Delta_up_down: 0.0217365
#   Move  Remove Delta_down_up: 0.0212245
#   Move  Remove Delta_down_down: 0.0276795
# Move  Shift one operator: 0.827338
# [Rank 0] Warmup lasted: 0.323215 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.648638 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 8.0508
# Auto-correlation time: 2.62123
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
#
#
# Iteration = 10 / 10
# -0.5*c_dag('down',0)*c('down',0) + -0.5*c_dag('up',0)*c('up',0) + 1*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:06  31% ETA 00:00:00 cycle 1557 of 5000
# 22:16:07 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:07  15% ETA 00:00:00 cycle 1534 of 10000
# 22:16:07 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00108387
# Average order         | 0.000231508
# Average sign          | 0.00024577
# G_tau measure         | 0.00172755
# Total measure time    | 0.00328871
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.137111
#   Move  Insert Delta_up: 0.138103
#   Move  Insert Delta_down: 0.136124
# Move set Remove two operators: 0.136868
#   Move  Remove Delta_up: 0.136946
#   Move  Remove Delta_down: 0.136791
# Move set Insert four operators: 0.0244609
#   Move  Insert Delta_up_up: 0.0282271
#   Move  Insert Delta_up_down: 0.0201996
#   Move  Insert Delta_down_up: 0.0211721
#   Move  Insert Delta_down_down: 0.0281887
# Move set Remove four operators: 0.0246914
#   Move  Remove Delta_up_up: 0.0285174
#   Move  Remove Delta_up_down: 0.0222497
#   Move  Remove Delta_down_up: 0.0207763
#   Move  Remove Delta_down_down: 0.0272237
# Move  Shift one operator: 0.831942
# [Rank 0] Warmup lasted: 0.321829 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.65251 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 8.1865
# Auto-correlation time: 1.6264
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# U = 2.0
# -0.5*c_dag('down',0)*c('down',0) + -0.5*c_dag('up',0)*c('up',0) + 1*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:07  30% ETA 00:00:00 cycle 1548 of 5000
# 22:16:08 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:08  15% ETA 00:00:00 cycle 1550 of 10000
# 22:16:08 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00109359
# Average order         | 0.000229326
# Average sign          | 0.000230244
# G_tau measure         | 0.00160319
# Total measure time    | 0.00315635
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.136865
#   Move  Insert Delta_up: 0.136144
#   Move  Insert Delta_down: 0.137585
# Move set Remove two operators: 0.136487
#   Move  Remove Delta_up: 0.136087
#   Move  Remove Delta_down: 0.136888
# Move set Insert four operators: 0.0247125
#   Move  Insert Delta_up_up: 0.0291157
#   Move  Insert Delta_up_down: 0.0200999
#   Move  Insert Delta_down_up: 0.0207065
#   Move  Insert Delta_down_down: 0.0288711
# Move set Remove four operators: 0.0250504
#   Move  Remove Delta_up_up: 0.0279124
#   Move  Remove Delta_up_down: 0.0211228
#   Move  Remove Delta_down_up: 0.0220934
#   Move  Remove Delta_down_down: 0.0291107
# Move  Shift one operator: 0.830829
# [Rank 0] Warmup lasted: 0.324269 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.650071 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 8.1232
# Auto-correlation time: 2.62633
#
#
# Iteration = 1 / 10
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:08  33% ETA 00:00:00 cycle 1687 of 5000
# 22:16:09 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:09  16% ETA 00:00:00 cycle 1664 of 10000
# 22:16:09 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00108961
# Average order         | 0.000229816
# Average sign          | 0.00023466
# G_tau measure         | 0.00205396
# Total measure time    | 0.00360805
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.125473
#   Move  Insert Delta_up: 0.125155
#   Move  Insert Delta_down: 0.12579
# Move set Remove two operators: 0.125671
#   Move  Remove Delta_up: 0.125471
#   Move  Remove Delta_down
#
# Iteration = 2 / 10
# : 0.125871
# Move set Insert four operators: 0.0246864
#   Move  Insert Delta_up_up: 0.0268028
#   Move  Insert Delta_up_down: 0.0216412
#   Move  Insert Delta_down_up: 0.0227946
#   Move  Insert Delta_down_down: 0.0274721
# Move set Remove four operators: 0.0247316
#   Move  Remove Delta_up_up: 0.0269343
#   Move  Remove Delta_up_down: 0.0224071
#   Move  Remove Delta_down_up: 0.0220799
#   Move  Remove Delta_down_down: 0.0275138
# Move  Shift one operator: 0.698464
# [Rank 0] Warmup lasted: 0.297706 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.601196 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.6646
# Auto-correlation time: 3.28392
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:09  34% ETA 00:00:00 cycle 1706 of 5000
# 22:16:10 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:10  17% ETA 00:00:00 cycle 1715 of 10000
# 22:16:10 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00110363
# Average order         | 0.000232702
# Average sign          | 0.00023596
# G_tau measure         | 0.00150754
# Total measure time    | 0.00307983
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.130538
#   Move  Insert Delta_up: 0.131357
#   Move  Insert Delta_down: 0.129719
# Move set Remove two operators: 0.130263
#   Move  Remove Delta_up: 0.131032
#   Move  Remove Delta_down: 0.129493
# Move set Insert four operators: 0.0270564
#   Move  Insert Delta_up_up: 0.0299128
#   Move  Insert Delta_up_down: 0.0238143
#   Move  Insert Delta_down_up: 0.0254887
#   Move  Ins
#
# Iteration = 3 / 10
# ert Delta_down_down: 0.0289647
# Move set Remove four operators: 0.0271909
#   Move  Remove Delta_up_up: 0.0297328
#   Move  Remove Delta_up_down: 0.0259022
#   Move  Remove Delta_down_up: 0.0248111
#   Move  Remove Delta_down_down: 0.028303
# Move  Shift one operator: 0.678488
# [Rank 0] Warmup lasted: 0.292087 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.590065 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.3414
# Auto-correlation time: 2.59554
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:10  34% ETA 00:00:00 cycle 1721 of 5000
# 22:16:10 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:11  16% ETA 00:00:00 cycle 1688 of 10000
# 22:16:11 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00107435
# Average order         | 0.000227853
# Average sign          | 0.000232929
# G_tau measure         | 0.00200559
# Total measure time    | 0.00354072
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.127771
#   Move  Insert Delta_up: 0.128914
#   Move  Insert Delta_down: 0.12663
# Move set Remove two operators: 0.128221
#   Move  Remove Delta_up: 0.129491
#   Move  Remove Delta_down: 0.12695
# Move set Insert four operators: 0.0256648
#   Move  Insert Delta_up_up: 0.0283026
#   Move  Insert Delta_up_down: 0.0233949
#   Move  Insert Delta_down_up: 0.0232993
#   Move  Insert Delta_down_down: 0.0276514
# Move set Remove four operators: 0.0258822
#   Move  Remove Delta_up_up: 0.0277958
#   Move  Remove Delta_up_down: 0.0234759
#   Move  Remove Delta_down_up: 0.0250552
#   Move  Remove Delta_down_down: 0.0272286
# Move  Shift one operator: 0.684272
# [Rank 0] Warmup lasted: 0.293884 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.593818 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.4618
# Auto-correlation time: 2.75014
#
#
# Iteration = 4 / 10
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:11  34% ETA 00:00:00 cycle 1701 of 5000
# 22:16:11 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:11  17% ETA 00:00:00 cycle 1719 of 10000
# 22:16:12 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00110005
# Average order         | 0.000231586
# Average sign          | 0.000234202
# G_tau measure         | 0.00192941
# Total measure time    | 0.00349525
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.131699
#   Move  Insert Delta_up: 0.130628
#   Move  Insert Delta_down: 0.13277
# Move set Remove two operators: 0.130431
#   Move  Remove Delta_up: 0.129478
#   Move  Remove Delta_dow
#
# Iteration = 5 / 10
# n: 0.131386
# Move set Insert four operators: 0.0271569
#   Move  Insert Delta_up_up: 0.0281887
#   Move  Insert Delta_up_down: 0.0258805
#   Move  Insert Delta_down_up: 0.024888
#   Move  Insert Delta_down_down: 0.0296566
# Move set Remove four operators: 0.0275519
#   Move  Remove Delta_up_up: 0.0287468
#   Move  Remove Delta_up_down: 0.0255961
#   Move  Remove Delta_down_up: 0.0253231
#   Move  Remove Delta_down_down: 0.0305499
# Move  Shift one operator: 0.672073
# [Rank 0] Warmup lasted: 0.290778 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.585419 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.2379
# Auto-correlation time: 2.34046
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:12  34% ETA 00:00:00 cycle 1712 of 5000
# 22:16:12 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:12  17% ETA 00:00:00 cycle 1719 of 10000
# 22:16:13 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00108505
# Average order         | 0.000230303
# Average sign          | 0.000233701
# G_tau measure         | 0.00192776
# Total measure time    | 0.00347682
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.131567
#   Move  Insert Delta_up: 0.133715
#   Move  Insert Delta_down: 0.129426
# Move set Remove two operators: 0.130663
#   Move  Remove Delta_up: 0.13311
#   Move  Remove Delta_dow
#
# Iteration = 6 / 10
# n: 0.128214
# Move set Insert four operators: 0.0276007
#   Move  Insert Delta_up_up: 0.0306565
#   Move  Insert Delta_up_down: 0.0254948
#   Move  Insert Delta_down_up: 0.025725
#   Move  Insert Delta_down_down: 0.0285063
# Move set Remove four operators: 0.0284674
#   Move  Remove Delta_up_up: 0.0316303
#   Move  Remove Delta_up_down: 0.0252882
#   Move  Remove Delta_down_up: 0.0267753
#   Move  Remove Delta_down_down: 0.0301962
# Move  Shift one operator: 0.677651
# [Rank 0] Warmup lasted: 0.291761 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.588345 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.2701
# Auto-correlation time: 2.43454
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:13  34% ETA 00:00:00 cycle 1719 of 5000
# 22:16:13 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:13  16% ETA 00:00:00 cycle 1697 of 10000
# 22:16:14 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00109164
# Average order         | 0.000231671
# Average sign          | 0.00023731
# G_tau measure         | 0.00156541
# Total measure time    | 0.00312603
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.127818
#   Move  Insert Delta_up: 0.127863
#   Move  Insert Delta_down: 0.127773
# Move set Remove two operators: 0.128597
#   Move  Remove Delta_up: 0.128824
#   Move  Remove Delta_dow
#
# Iteration = 7 / 10
# n: 0.12837
# Move set Insert four operators: 0.0270821
#   Move  Insert Delta_up_up: 0.0302706
#   Move  Insert Delta_up_down: 0.0244285
#   Move  Insert Delta_down_up: 0.0250341
#   Move  Insert Delta_down_down: 0.0285486
# Move set Remove four operators: 0.0268681
#   Move  Remove Delta_up_up: 0.029369
#   Move  Remove Delta_up_down: 0.0251997
#   Move  Remove Delta_down_up: 0.0249889
#   Move  Remove Delta_down_down: 0.0279296
# Move  Shift one operator: 0.680676
# [Rank 0] Warmup lasted: 0.292504 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.591052 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.4495
# Auto-correlation time: 4.93486
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
#
#
# Iteration = 8 / 10
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:14  33% ETA 00:00:00 cycle 1696 of 5000
# 22:16:14 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:14  16% ETA 00:00:00 cycle 1680 of 10000
# 22:16:15 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00111843
# Average order         | 0.000232687
# Average sign          | 0.000234153
# G_tau measure         | 0.00156495
# Total measure time    | 0.00315022
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.128634
#   Move  Insert Delta_up: 0.128384
#   Move  Insert Delta_down: 0.128883
# Move set Remove two operators: 0.129022
#   Move  Remove Delta_up: 0.12886
#   Move  Remove Delta_down: 0.129184
# Move set Insert four operators: 0.0264743
#   Move  Insert Delta_up_up: 0.0287922
#   Move  Insert Delta_up_down: 0.0235365
#   Move  Insert Delta_down_up: 0.0237667
#   Move  Insert Delta_down_down: 0.0297869
# Move set Remove four operators: 0.026674
#   Move  Remove Delta_up_up: 0.0276172
#   Move  Remove Delta_up_down: 0.0253356
#   Move  Remove Delta_down_up: 0.0249358
#   Move  Remove Delta_down_down: 0.0288193
# Move  Shift one operator: 0.681544
# [Rank 0] Warmup lasted: 0.294508 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.591398 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.4043
# Auto-correlation time: 2.96938
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
#
#
# Iteration = 9 / 10
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:15  33% ETA 00:00:00 cycle 1694 of 5000
# 22:16:15 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:15  17% ETA 00:00:00 cycle 1708 of 10000
# 22:16:16 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.0010948
# Average order         | 0.000229815
# Average sign          | 0.000231887
# G_tau measure         | 0.00149936
# Total measure time    | 0.00305586
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.132223
#   Move  Insert Delta_up: 0.132401
#   Move  Insert Delta_down: 0.132044
# Move set Remove two operators: 0.129861
#   Move  Remove Delta_up: 0.12952
#   Move  Remove Delta_down: 0.130201
# Move set Insert four operators: 0.0269862
#   Move  Insert Delta_up_up: 0.0305089
#   Move  Insert Delta_up_down: 0.0243726
#   Move  Insert Delta_down_up: 0.0237724
#   Move  Insert Delta_down_down: 0.0292517
# Move set Remove four operators: 0.0282147
#   Move  Remove Delta_up_up: 0.0309872
#   Move  Remove Delta_up_down: 0.0276375
#   Move  Remove Delta_down_up: 0.0263264
#   Move  Remove Delta_down_down: 0.0279213
# Move  Shift one operator: 0.677678
# [Rank 0] Warmup lasted: 0.2931 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.587576 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.242
# Auto-correlation time: 2.74536
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:16  34% ETA 00:00:00 cycle 1712 of 5000
# 22:16:16 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:16  17% ETA 00:00:00 cycle 1706 of 10000
# 22:16:16 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00110887
# Average order         | 0.000228642
# Average sign          | 0.00023386
# G_tau measure         | 0.00144145
# Total measure time    | 0.00301282
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.130937
#   Move  Insert Delta_up: 0.132246
#   Move  Insert Delta_down: 0.12963
# Move set Remove two operators: 0.131236
#   Move  Remove Delta_up: 0.132046
#   Move  Remove Delta_down
#
# Iteration = 10 / 10
# : 0.130424
# Move set Insert four operators: 0.0276569
#   Move  Insert Delta_up_up: 0.0298347
#   Move  Insert Delta_up_down: 0.0258974
#   Move  Insert Delta_down_up: 0.0245561
#   Move  Insert Delta_down_down: 0.0303272
# Move set Remove four operators: 0.0277909
#   Move  Remove Delta_up_up: 0.0306308
#   Move  Remove Delta_up_down: 0.0249253
#   Move  Remove Delta_down_up: 0.0255935
#   Move  Remove Delta_down_down: 0.0300287
# Move  Shift one operator: 0.675164
# [Rank 0] Warmup lasted: 0.292344 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.586177 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.2563
# Auto-correlation time: 4.01083
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:17  33% ETA 00:00:00 cycle 1686 of 5000
# 22:16:17 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:17  17% ETA 00:00:00 cycle 1710 of 10000
# 22:16:17 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00117741
# Average order         | 0.000235284
# Average sign          | 0.000240092
# G_tau measure         | 0.00247901
# Total measure time    | 0.0041318
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.131003
#   Move  Insert Delta_up: 0.131509
#   Move  Insert Delta_down: 0.1305
# Move set Remove two operators: 0.130783
#   Move  Remove Delta_up: 0.130729
#   Move  Remove Delta_down: 0.130837
# Move set Insert four operators: 0.0263867
#   Move  Insert Delta_up_up: 0.0290737
#   Move  Insert Delta_up_down: 0.0231511
#   Move  Insert Delta_down_up: 0.0250389
#   Move  Insert Delta_down_down: 0.0282522
# Move set Remove four operators: 0.0267621
#   Move  Remove Delta_up_up: 0.0297348
#   Move  Remove Delta_up_down: 0.0242209
#   Move  Remove Delta_down_up: 0.0247709
#   Move  Remove Delta_down_down: 0.0283461
# Move  Shift one operator: 0.67701
# [Rank 0] Warmup lasted: 0.294512 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.618479 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.3268
# Auto-correlation time: 0.794236
# U = 3.0
#
#
# Iteration = 1 / 10
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1.5*c_dag('down',0)*c('down',0) + -1.5*c_dag('up',0)*c('up',0) + 3*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
#
#
# Iteration = 2 / 10
# Found 4 subspaces.
#
# Warming up ...
# 22:16:18  36% ETA 00:00:00 cycle 1847 of 5000
# 22:16:18 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:18  18% ETA 00:00:00 cycle 1822 of 10000
# 22:16:18 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00113781
# Average order         | 0.000230775
# Average sign          | 0.00023725
# G_tau measure         | 0.00152149
# Total measure time    | 0.00312733
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.112247
#   Move  Insert Delta_up: 0.113798
#   Move  Insert Delta_down: 0.110696
# Move set Remove two operators: 0.111523
#   Move  Remove Delta_up: 0.11241
#   Move  Remove Delta_down: 0.110636
# Move set Insert four operators: 0.0226176
#   Move  Insert Delta_up_up: 0.0237627
#   Move  Insert Delta_up_down: 0.0205814
#   Move  Insert Delta_down_up: 0.0218449
#   Move  Insert Delta_down_down: 0.0242896
# Move set Remove four operators: 0.0232029
#   Move  Remove Delta_up_up: 0.0245147
#   Move  Remove Delta_up_down: 0.022101
#   Move  Remove Delta_down_up: 0.0226071
#   Move  Remove Delta_down_down: 0.0235938
# Move  Shift one operator: 0.568929
# [Rank 0] Warmup lasted: 0.270008 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.542199 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.0545
# Auto-correlation time: 2.35299
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
#
#
# Iteration = 3 / 10
# -1.5*c_dag('down',0)*c('down',0) + -1.5*c_dag('up',0)*c('up',0) + 3*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:18  39% ETA 00:00:00 cycle 1993 of 5000
# 22:16:19 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:19  19% ETA 00:00:00 cycle 1959 of 10000
# 22:16:19 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00110966
# Average order         | 0.000232897
# Average sign          | 0.000233661
# G_tau measure         | 0.00217556
# Total measure time    | 0.00375178
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.119575
#   Move  Insert Delta_up: 0.118774
#   Move  Insert Delta_down: 0.120375
# Move set Remove two operators: 0.118525
#   Move  Remove Delta_up: 0.117625
#   Move  Remove Delta_down: 0.119424
# Move set Insert four operators: 0.0260688
#   Move  Insert Delta_up_up: 0.0249124
#   Move  Insert Delta_up_down: 0.0259468
#   Move  Insert Delta_down_up: 0.028224
#   Move  Insert Delta_down_down: 0.0251899
# Move set Remove four operators: 0.0267536
#   Move  Remove Delta_up_up: 0.026036
#   Move  Remove Delta_up_down: 0.0281528
#   Move  Remove Delta_down_up: 0.0270466
#   Move  Remove Delta_down_down: 0.0257593
# Move  Shift one operator: 0.509178
# [Rank 0] Warmup lasted: 0.249613 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.5083 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 6.1244
# Auto-correlation time: 3.95588
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1.5*c_dag('down',0)*c('down',0) + -1.5*c_dag('up',0)*c('up',0) + 3*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:19  39% ETA 00:00:00 cycle 1989 of 5000
# 22:16:19 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:19  19% ETA 00:00:00 cycle 1977 of 10000
# 22:16:20 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00106891
# Average order         | 0.00022829
# Average sign          | 0.000233732
# G_tau measure         | 0.00246651
# Total measure time    | 0.00399745
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.116787
#   Move  Insert Delta_up: 0.116187
#   Move  Insert Delta_down: 0.117384
# Move set Remove two operators: 0.116633
#   Move  Remove Delta_up: 0.116475
#   Move  Remove Delta
#
# Iteration = 4 / 10
# _down: 0.11679
# Move set Insert four operators: 0.0259455
#   Move  Insert Delta_up_up: 0.026201
#   Move  Insert Delta_up_down: 0.0258814
#   Move  Insert Delta_down_up: 0.0264806
#   Move  Insert Delta_down_down: 0.0252178
# Move set Remove four operators: 0.0264393
#   Move  Remove Delta_up_up: 0.0269715
#   Move  Remove Delta_up_down: 0.0248916
#   Move  Remove Delta_down_up: 0.026979
#   Move  Remove Delta_down_down: 0.0269331
# Move  Shift one operator: 0.520079
# [Rank 0] Warmup lasted: 0.253055 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.514129 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 6.2308
# Auto-correlation time: 5.61951
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1.5*c_dag('down',0)*c('down',0) + -1.5*c_dag('up',0)*c('up',0) + 3*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:20  39% ETA 00:00:00 cycle 1958 of 5000
# 22:16:20 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:20  19% ETA 00:00:00 cycle 1975 of 10000
# 22:16:21 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00108585
# Average order         | 0.0002251
# Average sign          | 0.000233383
# G_tau measure         | 0.00124458
# Total measure time    | 0.00278891
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.119259
#   Move  Insert Delta_up: 0.118998
#   Move  Insert Delta_down: 0.11952
# Move set Remove two operators: 0.11786
#   Move  Remove Delta_up: 0.11722
#   Move  Remove Delta_do
#
# Iteration = 5 / 10
# wn: 0.118509
# Move set Insert four operators: 0.0262007
#   Move  Insert Delta_up_up: 0.0247214
#   Move  Insert Delta_up_down: 0.0280183
#   Move  Insert Delta_down_up: 0.0277204
#   Move  Insert Delta_down_down: 0.0243335
# Move set Remove four operators: 0.0270037
#   Move  Remove Delta_up_up: 0.0264473
#   Move  Remove Delta_up_down: 0.0269378
#   Move  Remove Delta_down_up: 0.0272082
#   Move  Remove Delta_down_down: 0.027421
# Move  Shift one operator: 0.514142
# [Rank 0] Warmup lasted: 0.25236 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.50767 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 6.1344
# Auto-correlation time: 5.42356
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1.5*c_dag('down',0)*c('down',0) + -1.5*c_dag('up',0)*c('up',0) + 3*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:21  38% ETA 00:00:00 cycle 1948 of 5000
# 22:16:21 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:21  19% ETA 00:00:00 cycle 1931 of 10000
# 22:16:21 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00111254
# Average order         | 0.000235038
# Average sign          | 0.00023013
# G_tau measure         | 0.00185597
# Total measure time    | 0.00343368
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.12076
#   Move  Insert Delta_up: 0.121218
#   Move  Insert Delta_down: 0.120303
# Move set Remove two operators: 0.121201
#   Move  Remove Delta_up: 0.121831
#   Move  Remove Delta_down: 0.120573
# Move set Insert four operators: 0.0267368
#   Move  Insert Delta_up_up: 0.026411
#   Move  Insert Delta_up_down: 0.0274809
#   Move  Insert Delta_down_up: 0.0270616
#   Move  Inser
#
# Iteration = 6 / 10
# t Delta_down_down: 0.0260013
# Move set Remove four operators: 0.0265407
#   Move  Remove Delta_up_up: 0.025342
#   Move  Remove Delta_up_down: 0.0281685
#   Move  Remove Delta_down_up: 0.0271009
#   Move  Remove Delta_down_down: 0.0255323
# Move  Shift one operator: 0.515457
# [Rank 0] Warmup lasted: 0.253145 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.511529 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 6.1383
# Auto-correlation time: 3.12987
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1.5*c_dag('down',0)*c('down',0) + -1.5*c_dag('up',0)*c('up',0) + 3*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:22  39% ETA 00:00:00 cycle 1976 of 5000
# 22:16:22 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:22  19% ETA 00:00:00 cycle 1944 of 10000
# 22:16:22 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00112062
# Average order         | 0.000230762
# Average sign          | 0.000231648
# G_tau measure         | 0.00211135
# Total measure time    | 0.00369439
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.117368
#   Move  Insert Delta_up: 0.117308
#   Move  Insert Delta_down: 0.117427
# Move set Remove two operators: 0.117241
#   Move  Remove Delta_up: 0.116591
#   Move  Remove Delta_down: 0.117894
# Move set Insert four operators: 0.0261457
#   Move  Insert Delta_up_up: 0.0261487
#   Move  Insert Delta_up_down: 0.0253525
#   Move  Insert Delta_down_up: 0.0266688
#   Move  Insert Delta_down_down: 0.0264136
# Move set Remove four operators: 0.0265045
#   Move  Remove Delta_up_up: 0.0252665
#   Move  Remove Delta_up_down: 0.0275678
#   Move  Remove Delta_down_up: 0.0282901
#   Move  Remove Delta_down_down: 0.024888
# Move  Shift one operator: 0.512693
# [Rank 0] Warmup lasted: 0.254941 seconds [00:00:00]
# ...
# 22:16:57  64% ETA 00:00:00 cycle 6402 of 10000
# 22:16:57 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00112436
# Average order         | 0.000226855
# Average sign          | 0.000226114
# G_tau measure         | 0.000716934
# Total measure time    | 0.00229426
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.0532849
#   Move  Insert Delta_up: 0.0522147
#   Move  Insert Delta_down: 0.0543555
# Move set Remove two operators: 0.053342
#   Move  Remove Delta_up: 0.0532922
#   Move  Remove Delta_down: 0.0533916
# Move set Insert four operators: 0.00446188
#   Move  Insert Delta_up_up: 0.00427029
#   Move  Insert Delta_up_down: 0.0056238
#   Move  Insert Delta_down_up: 0.00476629
#   Move  Insert Delta_down_down: 0.0031903
# Move set Remove four operators: 0.00436633
#   Move  Remove Delta_up_up: 0.00327022
#   Move  Remove Delta_up_down: 0.00473538
#   Move  Remove Delta_down_up: 0.00557037
#   Move  Remove Delta_down_down: 0.00387195
# Move  Shift one operator: 0.0277647
# [Rank 0] Warmup lasted: 0.0758085 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.154993 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 0.8927
# Auto-correlation time: 2.53428
#
#
# Iteration = 4 / 10
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -6*c_dag('down',0)*c('down',0) + -6*c_dag('up',0)*c('up',0) + 12*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:57 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:57  65% ETA 00:00:00 cycle 6572 of 10000
# 22:16:57 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00114002
# Average order         | 0.000224414
# Average sign          | 0.000225962
# G_tau measure         | 0.000630806
# Total measure time    | 0.0022212
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.0487876
#   Move  Insert Delta_up: 0.0475343
#   Move  Insert Delta_down: 0.0500452
# Move set Remove two operators: 0.0492262
#   Move  Remove Delta_up: 0.0486641
#   Move  Remove Delta_down: 0.0497856
# Move set Insert four operators: 0.00317577
#   Move  Insert Delta_up_up: 0.0035957
#   Move  Insert Delta_up_down: 0.00350054
#   Move  Insert Delta_down_up: 0.00284136
#   Move  Insert Delta_down_down: 0.00275857
# Move set Remove four operators: 0.00292205
#   Move  Remove Delta_up_up: 0.00258701
#   Move  Remove Delta_up_down: 0.00302885
#   Move  Remove Delta_down_up: 0.00338107
#   Move  Remove Delta_down_down: 0.0026844
# Move  Shift one operator: 0.0236387
# [Rank 0] Warmup lasted: 0.073765 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.152073 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 0.9998
# Average order: 0.8792
# Auto-correlation time: 3.32021
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -6*c_dag('down',0)*c('down',0) + -6*c_dag('up',0)*c(
#
# Iteration = 5 / 10
# 'up',0) + 12*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:57 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:57  64% ETA 00:00:00 cycle 6428 of 10000
# 22:16:57 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00116419
# Average order         | 0.000224644
# Average sign          | 0.000224573
# G_tau measure         | 0.000638243
# Total measure time    | 0.00225165
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.048189
#   Move  Insert Delta_up: 0.0475752
#   Move  Insert Delta_down: 0.048804
# Move set Remove two operators: 0.048684
#   Move  Remove Delta_up: 0.0485661
#   Move  Remove Delta_down: 0.0488014
# Move set Insert four operators: 0.00280902
#   Move  Insert Delta_up_up: 0.0032411
# 1
#   Move  Insert Delta_up_down: 0.00320282
#   Move  Insert Delta_down_up: 0.00247802
#   Move  Insert Delta_down_down: 0.0023114
# Move set Remove four operators: 0.0025366
#   Move  Remove Delta_up_up: 0.00258148
#   Move  Remove Delta_up_down: 0.00246217
#   Move  Remove Delta_down_up: 0.00286055
#   Move  Remove Delta_down_down: 0.00224081
# Move  Shift one operator: 0.0246712
# [Rank 0] Warmup lasted: 0.0758323 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.154629 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 0.9992
# Average order: 0.9191
# Auto-correlation time: 3.93015
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
#
#
# Iteration = 6 / 10
# -6*c_dag('down',0)*c('down',0) + -6*c_dag('up',0)*c('up',0) + 12*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:58 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:58  64% ETA 00:00:00 cycle 6476 of 10000
# 22:16:58 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00116459
# Average order         | 0.000224906
# Average sign          | 0.000229134
# G_tau measure         | 0.000635063
# Total measure time    | 0.0022537
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.0482681
#   Move  Insert Delta_up: 0.0473526
#   Move  Insert Delta_down: 0.0491879
# Move set Remove two operators: 0.0482165
#   Move  Remove Delta_up: 0.0481162
#   Move  Remove Delta_down: 0.0483167
# Move set Insert four operators: 0.00294627
#   Move  Insert Delta_up_up: 0.00344064
#   Move  Insert Delta_up_down: 0.00291673
#   Move  Insert Delta_down_up: 0.00275251
#   Move  Insert Delta_down_down: 0.00267103
# Move set Remove four operators: 0.00298406
#   Move  Remove Delta_up_up: 0.0026251
#   Move  Remove Delta_up_down: 0.00285476
#   Move  Remove Delta_down_up: 0.00329326
#   Move  Remove Delta_down_down: 0.00315823
# Move  Shift one operator: 0.0246552
# [Rank 0] Warmup lasted: 0.0739468 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.153837 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 0.9972
# Average order: 0.911
# Auto-correlation time: 2.88386
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
#
#
# Iteration = 7 / 10
# -6*c_dag('down',0)*c('down',0) + -6*c_dag('up',0)*c('up',0) + 12*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:58 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:58  63% ETA 00:00:00 cycle 6397 of 10000
# 22:16:58 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00118952
# Average order         | 0.000228087
# Average sign          | 0.000227234
# G_tau measure         | 0.000806433
# Total measure time    | 0.00245128
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.048889
#   Move  Insert Delta_up: 0.0478555
#   Move  Insert Delta_down: 0.0499248
# Move set Remove two operators: 0.049152
#   Move  Remove Delta_up: 0.0484824
#   Move  Remove Delta_down: 0.0498193
# Move set Insert four operators: 0.003037
#   Move  Insert Delta_up_up: 0.00320006
#   Move  Insert Delta_up_down: 0.00327777
#   Move  Insert Delta_down_up: 0.0029207
#   Move  Insert Delta_down_down: 0.00274846
# Move set Remove four operators: 0.00285318
#   Move  Remove Delta_up_up: 0.00254032
#   Move  Remove Delta_up_down: 0.00293476
#   Move  Remove Delta_down_up: 0.00342016
#   Move  Remove Delta_down_down: 0.00251206
# Move  Shift one operator: 0.0245681
# [Rank 0] Warmup lasted: 0.0754295 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.155438 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 0.9988
# Average order: 0.8968
# Auto-correlation time: 4.21281
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -6*c_dag('down',0)*c('down',0) + -6*c_dag('up',0)*c('up',0) + 12*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:58 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:58  65% ETA 00:00:00 cycle 6513 of 10000
# 22:16:58 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00127096
# Average order         | 0.000236267
# Average sign          | 0.000235569
# G_tau measure         | 0.000693645
# Total measure time    | 0.00243644
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.0473094
#   Move  Insert Delta_up: 0.045965
#   Move  Insert Delta_down: 0.048656
# Move set Remove two operators: 0.0473527
#   Move  Remove Delta_up: 0.046369
#   Move  Remove Delta_down: 0.0483339
# Move set Insert four operators: 0.00272949
#   Move  Insert Delta_up_up: 0.00316006
#   Move  Insert Delta_up_down: 0.00287265
#   Move  Insert Delta_down_up: 0.00244254
#   Move  Insert Delta_down_down: 0.00243698
# Move set Remove four operators: 0.0026367
#   Move  Remove Delta_up_up: 0.00258314
#   Move  Remove Delta_up_down: 0.00241881
#   Move  Remove Delta_down_up: 0.00319259
#   Move  Remove Delta_down_down: 0.00235322
# Move  Shift one operator: 0.0233294
# [Rank 0] Warmup lasted: 0.0744892 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.18053 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 0.9988
# Average order: 0.8957
# Auto-correlation time: 2.51035
#
#
# Iteration = 8 / 10
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -6*c_dag('down',0)*c('down',0) + -6*c_dag('up',0)*c('up',0) + 12*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:58 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:58  64% ETA 00:00:00 cycle 6410 of 10000
# 22:16:59 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00121407
# Average order         | 0.000223865
# Average sign          | 0.000225593
# G_tau measure         | 0.00100719
# Total measure time    | 0.00267072
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.0488708
#   Move  Insert Delta_up: 0.048186
#   Move  Insert Delta_down: 0.0495586
# Move set Remove two operators: 0.0490466
#   Move  Remove Delta_up: 0.0489142
#   Move  Remove Delta_down: 0.049178
# Move set Insert four operators: 0.00282094
#   Move  Insert Delta_up_up: 0.00316907
#   Move  Insert Delta_up_down: 0.00295433
#   Move  Insert Delta_down_up: 0.00271815
#   Move  Insert Delta_down_down: 0.00243883
# Move
#
# Iteration = 9 / 10
# set Remove four operators: 0.00273748
#   Move  Remove Delta_up_up: 0.00262902
#   Move  Remove Delta_up_down: 0.00272997
#   Move  Remove Delta_down_up: 0.00314165
#   Move  Remove Delta_down_down: 0.00244518
# Move  Shift one operator: 0.0249233
# [Rank 0] Warmup lasted: 0.0742447 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.153988 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 0.998
# Average order: 0.9022
# Auto-correlation time: 3.34419
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
#
#
# Iteration = 10 / 10
# -6*c_dag('down',0)*c('down',0) + -6*c_dag('up',0)*c('up',0) + 12*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:59 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:59  65% ETA 00:00:00 cycle 6513 of 10000
# 22:16:59 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00114994
# Average order         | 0.000224124
# Average sign          | 0.00022249
# G_tau measure         | 0.000734621
# Total measure time    | 0.00233118
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.0492124
#   Move  Insert Delta_up: 0.0484356
#   Move  Insert Delta_down: 0.049993
# Move set Remove two operators: 0.0489308
#   Move  Remove Delta_up: 0.048871
#   Move  Remove Delta_down: 0.0489904
# Move set Insert four operators: 0.00273515
#   Move  Insert Delta_up_up: 0.00326991
#   Move  Insert Delta_up_down: 0.00276099
#   Move  Insert Delta_down_up: 0.00255092
#   Move  Insert Delta_down_down: 0.00235247
# Move set Remove four operators: 0.00280445
#   Move  Remove Delta_up_up: 0.00258294
#   Move  Remove Delta_up_down: 0.0028585
#   Move  Remove Delta_down_up: 0.00317801
#   Move  Remove Delta_down_down: 0.00259388
# Move  Shift one operator: 0.0245304
# [Rank 0] Warmup lasted: 0.0747334 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.151571 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 0.9986
# Average order: 0.8688
# Auto-correlation time: 3.98793
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -6*c_dag('down',0)*c('down',0) + -6*c_dag('up',0)*c('up',0) + 12*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:16:59 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:16:59  66% ETA 00:00:00 cycle 6613 of 10000
# 22:16:59 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure               | seconds
# Auto-correlation time | 0.00116107
# Average order         | 0.000224401
# Average sign          | 0.000228665
# G_tau measure         | 0.000952518
# Total measure time    | 0.00256666
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.0486702
#   Move  Insert Delta_up: 0.0479463
#   Move  Insert Delta_down: 0.0493956
# Move set Remove two operators: 0.0488597
#   Move  Remove Delta_up: 0.0489007
#   Move  Remove Delta_down: 0.0488189
# Move set Insert four operators: 0.00274177
#   Move  Insert Delta_up_up: 0.00356041
#   Move  Insert Delta_up_down: 0.00275273
#   Move  Insert Delta_down_up: 0.00252121
#   Move  Insert Delta_down_down: 0.00212272
# Move set Remove four operators: 0.00257861
#   Move  Remove Delta_up_up: 0.00265775
#   Move  Remove Delta_up_down: 0.00242603
#   Move  Remove Delta_down_up: 0.00290282
#   Move  Remove Delta_down_down: 0.00232661
# Move  Shift one operator: 0.0231697
# [Rank 0] Warmup lasted: 0.0739977 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.150389 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 0.9978
# Average order: 0.8281
# Auto-correlation time: 1.23047

# %% [markdown]
# <i class="fa fa-gear fa-x" style="color: #186391"></i> Exercise 2
# ----------
#
# Here, you will learn to analyze the output of the solver. As discussed, the Monte Carlo algorithm provide results on the
# Matsubara axis. This makes the analysis of the results slightly more delicate than if we had them directly on the real
# axis. When we used the IPT solver, we could see the Mott transition as the appearance of a gap in the spectral function.
# After the Monte Carlo run, we do not have the spectral function, so we will have to use some other criteria to decide, e.g.,
# if the system is metallic or insulating.
#
# Plot the Green's function at the end of the DMFT loops for several values of $U$ (say between 2 and 8). Focus on the extrapolation of the imaginary part of the Green's function to zero frequency. How does it change with $U$? Is there
# a way to see the Mott transition just by inspecting the imaginary part of the Green's function?

# %% [markdown]
# Solution 2
# ------------
#
# Start by reading the data from the archive and plot it.

# %%
from triqs.gf import *
from h5 import HDFArchive
# %matplotlib inline
from triqs.plot.mpl_interface import plt,oplot
import matplotlib as mpl
mpl.rcParams['figure.dpi']=100 

A1 = HDFArchive("data/one_band/half-U2.00.h5", 'r')
A2 = HDFArchive("data/one_band/half-U6.00.h5", 'r')

# Plot the Green's function of the last iteration
oplot(A1['G-9']['up'].imag, 'x', label='U = 2.0')
oplot(A2['G-9']['up'].imag, 'o', label='U = 6.0')
plt.ylabel("Im $G(i\\omega_n)$")

plt.xlim(0,10)
plt.ylim(-1,0.2)
plt.show()

# %% [markdown]
# As you can see, the behavior of the imaginary part is very different for the two values of $U$. When
# $U$ is small, the system is a metal and the imaginary part extrapolated to zero goes to a finite value.
# Instead, for large $U$, the system is a Mott insulator and the imaginary part goes to zero. The reason
# is that the extrapolation to zero is directly proportional to the density of states at the chemical
# potential. If the system is gapped, the density is zero; if the system is a metal, there is spectral
# weight and the density is finite. Therefore, even on the Matsubara axis, one has a way to decide if the
# system is metallic or not.

# %% [markdown]
# <i class="fa fa-gear fa-x" style="color: #186391"></i> Exercise 3
# ----------
#
# Do the same exercise as above, but analyze the self-energy. The noise usually gets bigger for larger frequencies, so just focus on the first few Matsubara frequencies. There the noise should not be too important. Again, by looking at the extrapolation to zero frequency of the imaginary part of the self-energy, can you tell where the Mott transition happens?

# %% [markdown]
# Solution 3
# ------------
#
# We now do the same for the self-energy.

# %%
A1 = HDFArchive("data/one_band/half-U2.00.h5", 'r')
A2 = HDFArchive("data/one_band/half-U6.00.h5", 'r')

# Plot the self-energy of the last iteration
oplot(A1['Sigma-9']['up'].imag, 'x', label='U = 2.0')
oplot(A2['Sigma-9']['up'].imag, 'o', label='U = 6.0')
plt.ylabel("$\\Sigma(i\\omega_n)$")

plt.xlim(0,5)
plt.ylim(-25,5)
plt.show()

# %% [markdown]
# <i class="fa fa-gear fa-x" style="color: #186391"></i> Exercise 4
# ----------
#
# A very useful quantity to measure the degree of correlation of a metal is the *quasiparticle weight* $Z$. It is defined as
#
# $$
# Z = \left[ 1 - \frac{\partial \text{Im} \Sigma(i\omega)}{\partial \omega} \big|_{\omega \rightarrow 0} \right]^{-1}
# $$
#
# For a non-interacting metal $Z=1$. As correlations appear, $Z$ gradually gets smaller. It reaches 0 at the Mott transition. Make a plot of $Z$ versus $U$ for the Bethe lattice Hubbard model.
#
# *Hint*: To access the values of $\Sigma_\uparrow(i\omega_n)$, you can use `S.Sigma['up'](n)`. This will be useful to numerically compute the derivative required to compute $Z$.

# %% [markdown]
# Solution 4
# ------------
#
# We estimate the derivative using the following approximation
#
# $$
# Z = \lim_{\omega_n \rightarrow 0} \Big( 1 - \frac{d\mathrm{Im} \Sigma(i\omega_n)}{di\omega_n} \Big)^{-1}
#   \sim \Big( 1 - \frac{\mathrm{Im} \Sigma(i\omega_0)}{\omega_0} \Big)^{-1}
# $$
#
# with $\omega_0 = \pi / \beta$ being the first Matsubara frequency.

# %%
import numpy as np
beta = 10
U_list = []
Z_list = []

for U in np.arange(1.0, 9.0):

    A = HDFArchive("data/one_band/half-U%.2f.h5"%U, 'r')
    Sigma = A['Sigma-9']

    Z = 1 / (1 - (Sigma['up'](0)[0,0].imag * beta / np.pi))
    U_list.append(U)
    Z_list.append(Z)

plt.plot(U_list, Z_list, '-o')
plt.xlabel('U')
plt.ylabel('Z')
plt.show()

# %% [markdown]
# <i class="fa fa-gear fa-x" style="color: #186391"></i> Exercise 5
# ----------
#
# Go back to your IPT code and try to modify it to extract the $Z$ versus $U$ curve. Compare this to the result you found in Exercise 4. Is the critical $U$ for the Mott transition similar to the one you found using CTHYB?

# %% [markdown]
# Solution 5
# ------------
#
# This is just the same script as we had earlier. We just add a couple of lines to extract $Z$.

# %%
from triqs.gf import *
from triqs.plot.mpl_interface import *

class IPTSolver:
    def __init__(self, beta):
        self.beta = beta

        # Matsubara frequency Green's functions
        iw_mesh = MeshImFreq(beta=beta, statistic='Fermion', n_iw=1001)
        self.G_iw = Gf(mesh=iw_mesh, target_shape=[1,1])
        self.G0_iw = self.G_iw.copy() # self.G0 will be set by the user after initialization
        self.Sigma_iw = self.G_iw.copy()

        # Imaginary time
        tau_mesh = MeshImTime(beta=beta, statistic='Fermion', n_tau=10001)
        self.G0_tau = Gf(mesh=tau_mesh, target_shape=[1,1])
        self.Sigma_tau = self.G0_tau.copy()

    def solve(self, U):
        self.G0_tau << Fourier(self.G0_iw)
        self.Sigma_tau << (U**2) * self.G0_tau * self.G0_tau * self.G0_tau
        self.Sigma_iw << Fourier(self.Sigma_tau)

        # Dyson
        self.G_iw << inverse(inverse(self.G0_iw) - self.Sigma_iw)

t = 1.0
beta = 10
n_loops = 30

S = IPTSolver(beta = beta)

U_list2 = []
Z_list2 = []

for U in np.arange(0.0, 9.0):

    S.G_iw << SemiCircular(2*t)
    for i in range(n_loops):

        S.G0_iw << inverse( iOmega_n - t**2 * S.G_iw )
        S.solve(U = U)


    Z = 1 / (1 - (S.Sigma_iw(0)[0,0].imag * beta / np.pi))
    U_list2.append(U)
    Z_list2.append(Z)

    print(Z)

plt.plot(U_list2, Z_list2, '-o', label='IPT')
plt.plot(U_list, Z_list, '-x', label='CTQMC')
plt.xlabel('U')
plt.ylabel('Z')
plt.legend()
plt.show()
# Out:
# 1.0
# 0.924764780166112
# 0.7405705430914742
# 0.5233633052723756
# 0.3175449873604993
# 0.04849118124301345
# 0.01758405717600885
# 0.010908997591308938
# 0.007658355336913614

# %% [markdown]
# <i class="fa fa-gear fa-x" style="color: #186391"></i> Exercise 6
# ----------
#
# Try to analytically continue the Green's function on the real axis using the Pade approximation. What can
# you say about the result?

# %% [markdown]
# Solution 6
# ----------

# %%
from math import pi

with HDFArchive("data/one_band/half-U4.00.h5", 'r') as A:
    g = A['G-9']['up'][0,0]

w_mesh = MeshReFreq(window=(-5,5), n_w=1000)
g_real = Gf(mesh=w_mesh, target_shape=[])
g_real.set_from_pade(g)
oplot(-g_real.imag/pi, name=r"$\rho$")
plt.show()

# %% [markdown]
# The result is completely wrong. This is because of the noise in the Monte Carlo data. One would have to make much longer runs in order to reduce the error bars. The Pade approximation can be used only on very accurate data. When the noise is still quite large, one has to use different analytical continuation methods, like MaxEnt, which produces the following spectral function:
#
# <img src="imgs/maxent_Aw.png">
#
# Regardless of which package you use for MaxEnt, it is very important to remember that there are some important knobs with which one can play in MaxEnt that can substantially change the results, and so one must be very careful in its use!

# %% [markdown]
# <i class="fa fa-gear fa-x" style="color: #186391"></i> Exercise 7
# ----------
#
# In the last exercise we will analyze the impurity multiplets, the many-body states and their occupancies, using the CTHYB solver. To do this, we instruct the solver to measure the many-body density matrix of the impurity during sampling. This can be done at almost no additional numerical cost in CTHYB by passing the options `measure_density_matrix = True` and `use_norm_as_weight = True` to the `solve` call of the solver.
#
# Write a small script that measures the impurity density matrix for two U-values (metallic and insulating) and analyzes/compares the two solutions by saving the solver object after convergence is reached for both values. Then you can access the density matrix as `S.density_matrix`. We provide a function to analyze the multiplets within CTHYB: `triqs_cthyb.multiplet_tools.multiplet_analysis`. Have a look at the [documentation](https://triqs.github.io/cthyb/latest/guide/multiplet_analysis_notebook.html) to better understand how to use it. Use the code from exercise one to do this by extending it.
#
# The function `multiplet_analysis` will also characterize each impurity many-body state with its quantum numbers. What is the characteristic feature in the multiplet structure of the Mott insulating state?
#
# Tip: By default, printing a panda's data frame shows all stored multiplets sorted by occupation probability.

# %%
# Parameters of the model
t = 1.0
beta = 10
n_loops = 10

# Construct the impurity solver
S = Solver(beta = beta, gf_struct = [('up',1), ('down',1)] )

# run metallic U
U = 2.0

# This is a first guess for G
S.G_iw << SemiCircular(2*t)

# DMFT loop with self-consistency
for i in range(n_loops):
    print("\n\nIteration = %i / %i" % (i+1, n_loops))

    # Symmetrize the Green's function and use self-consistency
    g = 0.5 * ( S.G_iw['up'] + S.G_iw['down'] )
    for name, g0 in S.G0_iw:
        g0 << inverse( iOmega_n + U/2.0 - t**2 * g )

    # Solve the impurity problem
    S.solve(h_int = U * n('up',0) * n('down',0),   # Local Hamiltonian 
        n_cycles  = 10000,                           # Number of QMC cycles
        n_warmup_cycles = 5000,                      # Warmup cycles
        measure_density_matrix = True,
        use_norm_as_weight = True
        )

solver_U_met = S

################################

U = 8.0
S = Solver(beta = beta, gf_struct = [('up',1), ('down',1)] )
# This is a first guess for G
S.G_iw << SemiCircular(2*t)

# DMFT loop with self-consistency
for i in range(n_loops):
    print("\n\nIteration = %i / %i" % (i+1, n_loops))

    # Symmetrize the Green's function and use self-consistency
    g = 0.5 * ( S.G_iw['up'] + S.G_iw['down'] )
    for name, g0 in S.G0_iw:
        g0 << inverse( iOmega_n - t**2 * g )

    # Solve the impurity problem
    S.solve(h_int = U * n('up',0) * n('down',0),   # Local Hamiltonian
        n_cycles  = 10000,                         # Number of QMC cycles
        n_warmup_cycles = 5000,                    # Warmup cycles
        measure_density_matrix = True,
        use_norm_as_weight = True
        )

solver_U_ins = S
# Out:
# Iteration = 1 / 10
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Iteration = 2 / 10
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:17:02  33% ETA 00:00:00 cycle 1677 of 5000
# 22:17:02 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:17:02  16% ETA 00:00:00 cycle 1643 of 10000
# 22:17:03 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure                                    | seconds
# Auto-correlation time                      | 0.00133819
# Average order                              | 0.000231726
# Average sign                               | 0.000233558
# Density Matrix for local static observable | 0.00815534
# G_tau measure                              | 0.00174196
# Total measure time                         | 0.0117008
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.126531
#   Move  Insert Delta_up: 0.126914
#   Move  Insert Delta_down: 0.126149
# Move set Remove two operators:
# 0.12619
#   Move  Remove Delta_up: 0.126029
#   Move  Remove Delta_down: 0.126351
# Move set Insert four operators: 0.0247035
#   Move  Insert Delta_up_up: 0.0274999
#   Move  Insert Delta_up_down: 0.0215625
#   Move  Insert Delta_down_up: 0.0227945
#   Move  Insert Delta_down_down: 0.0269339
# Move set Remove four operators: 0.0249447
#   Move  Remove Delta_up_up: 0.0283648
#   Move  Remove Delta_up_down: 0.0228292
#   Move  Remove Delta_down_up: 0.0213184
#   Move  Remove Delta_down_down: 0.0273128
# Move  Shift one operator: 0.693784
# [Rank 0] Warmup lasted: 0.300697 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.605236 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.5979
# Auto-correlation time: 3.72498
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# T
# Iteration = 3 / 10he local Hamiltonian of the problem:
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:17:03  34% ETA 00:00:00 cycle 1702 of 5000
# 22:17:03 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:17:03  16% ETA 00:00:00 cycle 1689 of 10000
# 22:17:04 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure                                    | seconds
# Auto-correlation time                      | 0.00123978
# Average order                              | 0.000235277
# Average sign                               | 0.000234693
# Density Matrix for local static observable | 0.00810073
# G_tau measure                              | 0.00161867
# Total measure time                         | 0.0114292
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.130376
#   Move  Insert Delta_up: 0.130389
#   Move  Insert Delta_down: 0.130363
# Move set Remove two operators: 0.129503
#   Move  Remove Delta_up: 0.13009
#   Move  Remove Delta_down: 0.128916
# Move set Insert four operators: 0.0267524
#   Move  Insert Delta_up_up: 0.0304552
#   Move  Insert Delta_up_down: 0.0244587
#   Move  Insert Delta_down_up: 0.0246592
#   Move  Insert Delta_down_down: 0.0274126
# Move set Remove four operators: 0.0274155
#   Move  Remove Delta_up_up: 0.0300379
#   Move  Remove Delta_up_down: 0.0261638
#   Move  Remove Delta_down_up: 0.0245377
#   Move  Remove Delta_down_down: 0.0289506
# Move  Shift one operator: 0.671881
# [Rank 0] Warmup lasted: 0.290517 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.592996 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.2697
# Auto-correlation time: 2.97614
#
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:17:04  33% ETA 00:00:00 cycle 1687 of 5000
# 22:17:04 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:17:04  16% ETA 00:00:00 cycle 1659 of 10000
# 22:17:05 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure                                    | seconds
# Auto-correlation time                      | 0.00136127
# Average order                              | 0.000238104
# Average sign                               | 0.000239162
# Density Matrix for local static observable | 0.00815612
# G_tau measure                              | 0.00169621
# Total measure time                         | 0.0116909
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two opera
# tors: 0.129288
#   Move  Insert Delta_up: 0.127615
#   Move  Insert Delta_down: 0.130964
# Move set Remove two operators: 0.128037
#   Move  Remove Delta_up: 0.126385
#   Move  Remove Delta_down: 0.129697
# Move set Insert four operators: 0.0251244
#   Move  Insert Delta_up_up: 0.0273623
#   Move  Insert Delta_up_down: 0.0219406
#   Move  Insert Delta_down_up: 0.0234447
#   Move  Insert Delta_down_down: 0.0277279
# Move set Remove four operators: 0.0261643
#   Move  Remove Delta_up_up: 0.0278849
#   Move  Remove Delta_up_down: 0.0244398
#   Move  Remove Delta_down_up: 0.0237636
#   Move  Remove Delta_down_down: 0.0285669
# Move  Shift one operator: 0.687767
# [Rank 0] Warmup lasted: 0.296119 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.60296 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.5226
# Auto-correlation time: 2.5727
#
#
# Iteration = 4 / 10
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:17:05  34% ETA 00:00:00 cycle 1713 of 5000
# 22:17:05 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:17:05  16% ETA 00:00:00 cycle 1679 of 10000
# 22:17:06 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure                                    | seconds
# Auto-correlation time                      | 0.00139374
# Average order                              | 0.000228605
# Average sign                               | 0.000235036
# Density Matrix for local static observable | 0.00815646
# G_tau measure                              | 0.00281875
# Total measure time                         | 0.0128326
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.128976
#   Move  Insert Delta_up: 0.128583
#   Move  Insert Delta_down: 0.129367
# Move set Remove two operators:
#
# Iteration = 5 / 10
# 0.129343
#   Move  Remove Delta_up: 0.12947
#   Move  Remove Delta_down: 0.129216
# Move set Insert four operators: 0.0266265
#   Move  Insert Delta_up_up: 0.0294995
#   Move  Insert Delta_up_down: 0.0233716
#   Move  Insert Delta_down_up: 0.0254261
#   Move  Insert Delta_down_down: 0.0281797
# Move set Remove four operators: 0.0269285
#   Move  Remove Delta_up_up: 0.0292858
#   Move  Remove Delta_up_down: 0.0244087
#   Move  Remove Delta_down_up: 0.024402
#   Move  Remove Delta_down_down: 0.0296397
# Move  Shift one operator: 0.678065
# [Rank 0] Warmup lasted: 0.292236 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.599777 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.3514
# Auto-correlation time: 5.6108
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:17:06  34% ETA 00:00:00 cycle 1712 of 5000
# 22:17:06 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:17:06  16% ETA 00:00:00 cycle 1687 of 10000
# 22:17:07 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure                                    | seconds
# Auto-correlation time                      | 0.00132834
# Average order                              | 0.000228322
# Average sign                               | 0.000231791
# Density Matrix for local static observable | 0.00809175
# G_tau measure                              | 0.00154829
# Total measure time                         | 0.0114285
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.13125
#   Move  Insert Delta_up: 0.130292
#   Move  Insert Delta_down: 0.132202
# Move set Remove two operators: 0
#
# Iteration = 6 / 10
# .131256
#   Move  Remove Delta_up: 0.129898
#   Move  Remove Delta_down: 0.132619
# Move set Insert four operators: 0.0273576
#   Move  Insert Delta_up_up: 0.0284975
#   Move  Insert Delta_up_down: 0.026693
#   Move  Insert Delta_down_up: 0.0270638
#   Move  Insert Delta_down_down: 0.027165
# Move set Remove four operators: 0.0273454
#   Move  Remove Delta_up_up: 0.0308033
#   Move  Remove Delta_up_down: 0.0244641
#   Move  Remove Delta_down_up: 0.0246096
#   Move  Remove Delta_down_down: 0.0295232
# Move  Shift one operator: 0.680093
# [Rank 0] Warmup lasted: 0.292735 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.59891 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.348
# Auto-correlation time: 2.85328
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
#
#
# Iteration = 7 / 10
# Found 4 subspaces.
#
# Warming up ...
# 22:17:07  33% ETA 00:00:00 cycle 1673 of 5000
# 22:17:07 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:17:07  16% ETA 00:00:00 cycle 1679 of 10000
# 22:17:07 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure                                    | seconds
# Auto-correlation time                      | 0.0013939
# Average order                              | 0.000233111
# Average sign                               | 0.000239845
# Density Matrix for local static observable | 0.00810989
# G_tau measure                              | 0.00156844
# Total measure time                         | 0.0115452
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.129669
#   Move  Insert Delta_up: 0.131412
#   Move  Insert Delta_down: 0.127926
# Move set Remove two operators: 0.129422
#   Move  Remove Delta_up: 0.130478
#   Move  Remove Delta_down: 0.128366
# Move set Insert four operators: 0.026492
#   Move  Insert Delta_up_up: 0.0292283
#   Move  Insert Delta_up_down: 0.0247682
#   Move  Insert Delta_down_up: 0.0223555
#   Move  Insert Delta_down_down: 0.0296107
# Move set Remove four operators: 0.0267566
#   Move  Remove Delta_up_up: 0.0295104
#   Move  Remove Delta_up_down: 0.024014
#   Move  Remove Delta_down_up: 0.0253791
#   Move  Remove Delta_down_down: 0.0281611
# Move  Shift one operator: 0.678625
# [Rank 0] Warmup lasted: 0.295312 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.600138 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.4147
# Auto-correlation time: 3.48525
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:17:08  34% ETA 00:00:00 cycle 1699 of 5000
# 22:17:08 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:17:08  16% ETA 00:00:00 cycle 1684 of 10000
# 22:17:08 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure                                    | seconds
# Auto-correlation time                      | 0.00131452
# Average order                              | 0.000229404
# Average sign                               | 0.000233461
# Density Matrix for local static observable | 0.00811106
# G_tau measure                              | 0.00165854
# Total measure time                         | 0.011547
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.131118
#   Move  Insert Delta_up: 0.133188
#   Move  Insert Delta_down: 0.129061
# Move set Remove two operators:
#
# Iteration = 8 / 10
# 0.130928
#   Move  Remove Delta_up: 0.131478
#   Move  Remove Delta_down: 0.130379
# Move set Insert four operators: 0.0272792
#   Move  Insert Delta_up_up: 0.0291503
#   Move  Insert Delta_up_down: 0.0256956
#   Move  Insert Delta_down_up: 0.025002
#   Move  Insert Delta_down_down: 0.0292636
# Move set Remove four operators: 0.0274777
#   Move  Remove Delta_up_up: 0.0306139
#   Move  Remove Delta_up_down: 0.0265392
#   Move  Remove Delta_down_up: 0.0248253
#   Move  Remove Delta_down_down: 0.0279542
# Move  Shift one operator: 0.678111
# [Rank 0] Warmup lasted: 0.294986 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.59949 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.3734
# Auto-correlation time: 3.41825
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:17:09  34% ETA 00:00:00 cycle 1702 of 5000
# 22:17:09 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:17:09  16% ETA 00:00:00 cycle 1656 of 10000
# 22:17:09 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure                                    | seconds
# Auto-correlation time                      | 0.00133923
# Average order                              | 0.000232336
# Average sign                               | 0.000233305
# Density Matrix for local static observable | 0.00803343
# G_tau measure                              | 0.00156659
# Total measure time                         | 0.0114049
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.129764
#   Move  Insert Delta_up: 0.129274
#   Move  Insert Delta_down: 0.13025
# Move set Remove two operators: 0.129907
#   Move  Remove Delta_up: 0.12951
#   Move  Remove Delta_down: 0.130305
# Move set Insert four operators: 0.0267523
#   Move  Insert Delta_up_up: 0.0286962
#   Move  Insert Delta_up_down: 0.0239005
#   Move  Insert Delta_down_up: 0.026071
#   Move  Insert Delta_down_down: 0.0283079
# Move set Remove four operators: 0.0269265
#   Move  Remove Delta_up_up: 0.0291286
#   Move  Remove Delta_up_down: 0.0253468
#   Move  Remove Delta_down_up: 0.0239367
#   Move  Remove Delta_down_down: 0.0292959
# Move  Shift one operator: 0.675236
# [Rank 0] Warmup lasted: 0.294406 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.595755 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.2686
# Auto-correlation time: 1.69777
#
#
# Iteration = 9 / 10
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:17:09  34% ETA 00:00:00 cycle 1721 of 5000
# 22:17:10 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:17:10  16% ETA 00:00:00 cycle 1692 of 10000
# 22:17:10 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure                                    | seconds
# Auto-correlation time                      | 0.00133231
# Average order                              | 0.000225013
# Average sign                               | 0.000233997
# Density Matrix for local static observable | 0.00808097
# G_tau measure                              | 0.00154795
# Total measure time                         | 0.0114202
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.130918
#   Move  Insert Delta_up: 0.131818
#   Move  Insert Delta_down: 0.130023
# Move set Remove two operators: 0.130812
#   Move  Remove Delta_up: 0.131385
#   Move  Remove Delta_down: 0.130238
# Move set Insert four operators: 0.0271283
#   Move  Insert Delta_up_up: 0.0301968
#   Move  Insert Delta_up_down: 0.0254241
#   Move  Insert Delta_down_up: 0.0244098
#   Move  Insert Delta_down_down: 0.0284619
# Move set Remove four operators: 0.0273426
#   Move  Remove Delta_up_up: 0.0306934
#   Move  Remove Delta_up_down: 0.0233706
#   Move  Remove Delta_down_up: 0.0262203
#   Move  Remove Delta_down_down: 0.029125
# Move  Shift one operator: 0.680849
# [Rank 0] Warmup lasted: 0.292932 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.601 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.416
# Auto-correlation time: 2.62151
#
#
# Iteration = 10 / 10
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# -1*c_dag('down',0)*c('down',0) + -1*c_dag('up',0)*c('up',0) + 2*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
#
#
# Iteration = 1 / 10
# Found 4 subspaces.
#
# Warming up ...
# 22:17:10  34% ETA 00:00:00 cycle 1706 of 5000
# 22:17:11 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:17:11  16% ETA 00:00:00 cycle 1675 of 10000
# 22:17:11 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure                                    | seconds
# Auto-correlation time                      | 0.00137806
# Average order                              | 0.000230037
# Average sign                               | 0.000237012
# Density Matrix for local static observable | 0.00815583
# G_tau measure                              | 0.00236139
# Total measure time                         | 0.0123623
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.127546
#   Move  Insert Delta_up: 0.127982
#   Move  Insert Delta_down: 0.127113
# Move set Remove two operators: 0.12808
#   Move  Remove Delta_up: 0.128442
#   Move  Remove Delta_down: 0.127717
# Move set Insert four operators: 0.0267395
#   Move  Insert Delta_up_up: 0.0302059
#   Move  Insert Delta_up_down: 0.0241546
#   Move  Insert Delta_down_up: 0.024486
#   Move  Insert Delta_down_down: 0.0281028
# Move set Remove four operators: 0.026682
#   Move  Remove Delta_up_up: 0.0292921
#   Move  Remove Delta_up_down: 0.025327
#   Move  Remove Delta_down_up: 0.02453
#   Move  Remove Delta_down_down: 0.0275887
# Move  Shift one operator: 0.679496
# [Rank 0] Warmup lasted: 0.294636 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.605064 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 7.504
# Auto-correlation time: 3.84684
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# 8*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Iteration = 2 / 10Found 4 subspaces.
#
# Warming up ...
# 22:17:11  38% ETA 00:00:00 cycle 1928 of 5000
# 22:17:11 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:17:12  18% ETA 00:00:00 cycle 1889 of 10000
# 22:17:12 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure                                    | seconds
# Auto-correlation time                      | 0.00128872
# Average order                              | 0.000225645
# Average sign                               | 0.000232615
# Density Matrix for local static observable | 0.00742985
# G_tau measure                              | 0.00143309
# Total measure time                         | 0.0106099
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.0981697
#   Move  Insert Delta_up: 0.100728
#   Move  Insert Delta_down: 0.0956081
# Move set Remove two operators: 0.0976669
#   Move  Remove Delta_up: 0.100056
#   Move  Remove Delta_
# down: 0.0952858
# Move set Insert four operators: 0.0148436
#   Move  Insert Delta_up_up: 0.0174527
#   Move  Insert Delta_up_down: 0.0122583
#   Move  Insert Delta_down_up: 0.0119033
#   Move  Insert Delta_down_down: 0.0177238
# Move set Remove four operators: 0.0153993
#   Move  Remove Delta_up_up: 0.0183054
#   Move  Remove Delta_up_down: 0.0128083
#   Move  Remove Delta_down_up: 0.0130493
#   Move  Remove Delta_down_down: 0.0174559
# Move  Shift one operator: 0.696862
# [Rank 0] Warmup lasted: 0.259512 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.5263 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 6.383
# Auto-correlation time: 2.60812
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# 8*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
#
#
# Iteration = 3 / 10
# Found 4 subspaces.
#
# Warming up ...
# 22:17:12  42% ETA 00:00:00 cycle 2139 of 5000
# 22:17:12 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:17:12  20% ETA 00:00:00 cycle 2082 of 10000
# 22:17:13 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure                                    | seconds
# Auto-correlation time                      | 0.00123623
# Average order                              | 0.000227464
# Average sign                               | 0.000240041
# Density Matrix for local static observable | 0.00698331
# G_tau measure                              | 0.00124541
# Total measure time                         | 0.00993245
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.114151
#   Move  Insert Delta_up: 0.113294
#   Move  Insert Delta_down: 0.115016
# Move set Remove two operators: 0.114159
#   Move  Remove Delta_up: 0.1132
#   Move  Remove Delta_down: 0.115118
# Move set Insert four operators: 0.0184577
#   Move  Insert Delta_up_up: 0.0214698
#   Move  Insert Delta_up_down: 0.0156014
#   Move  Insert Delta_down_up: 0.0146697
#   Move  Insert Delta_down_down: 0.0221585
# Move set Remove four operators: 0.0187338
#   Move  Remove Delta_up_up: 0.0222883
#   Move  Remove Delta_up_down: 0.0165542
#   Move  Remove Delta_down_up: 0.0146923
#   Move  Remove Delta_down_down: 0.0214122
# Move  Shift one operator: 0.688393
# [Rank 0] Warmup lasted: 0.234551 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.477523 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 4.8859
# Auto-correlation time: 1.67832
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# 8*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
#
#
# Iteration = 4 / 10
# Found 4 subspaces.
#
# Warming up ...
# 22:17:13  41% ETA 00:00:00 cycle 2074 of 5000
# 22:17:13 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:17:13  20% ETA 00:00:00 cycle 2031 of 10000
# 22:17:13 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure                                    | seconds
# Auto-correlation time                      | 0.00126861
# Average order                              | 0.00022548
# Average sign                               | 0.000235531
# Density Matrix for local static observable | 0.00711774
# G_tau measure                              | 0.00129121
# Total measure time                         | 0.0101386
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.110181
#   Move  Insert Delta_up: 0.110367
#   Move  Insert Delta_down: 0.109993
# Move set Remove two operators: 0.111422
#   Move  Remove Delta_up: 0.111622
#   Move  Remove Delta_down: 0.111223
# Move set Insert four operators: 0.0183389
#   Move  Insert Delta_up_up: 0.020718
#   Move  Insert Delta_up_down: 0.015283
#   Move  Insert Delta_down_up: 0.0145192
#   Move  Insert Delta_down_down: 0.0228916
# Move set Remove four operators: 0.0178816
#   Move  Remove Delta_up_up: 0.0209298
#   Move  Remove Delta_up_down: 0.0145348
#   Move  Remove Delta_down_up: 0.0141254
#   Move  Remove Delta_down_down: 0.0219899
# Move  Shift one operator: 0.69167
# [Rank 0] Warmup lasted: 0.243546 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.497828 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 5.3543
# Auto-correlation time: 2.58133
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# 8*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:17:14  41% ETA 00:00:00 cycle 2077 of 5000
# 22:17:14 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:17:14  20% ETA 00:00:00 cycle 2023 of 10000
# 22:17:14 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure                                    | seconds
# Auto-correlation time                      | 0.00122564
# Average order                              | 0.000227974
# Average sign                               | 0.000236744
# Density Matrix for local static observable | 0.0070717
# G_tau measure                              | 0.001229
# Total measure time                         | 0.00999106
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.109949
#   Move  Insert Delta_up: 0.10986
#   Move  Insert Delta_down: 0.110039
# Move set Remove two operators: 0.109964
#   Move  Remove Delta_up: 0.110636
#   Move  Remove Delta_down: 0.109291
# Move set Insert four operators: 0.0182159
#   Move  Insert Delta_up_up: 0.0215178
#   Move  Insert Delta_up_down: 0.015512
#   Move  Insert Delta_down_up: 0.0153834
#   Move  Insert Delta_down_down: 0.0204318
# Move set Remove four operators: 0.0183338
#   Move  Remove Delta_up_up: 0.0213988
#   Move  Remove Delta_up_down: 0.0159109
#   Move  Remove Delta_down_up: 0.0149632
#   Move  Remove Delta_down_down: 0.0210871
# Move  Shift one operator: 0.688337
# [Rank 0] Warmup lasted: 0.241815 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.492164 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 5.2548
# Auto-correlation time: 2.54552
#
#
# Iteration = 5 / 10
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# 8*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
#
#
# Iteration = 6 / 10
# Found 4 subspaces.
#
# Warming up ...
# 22:17:14  41% ETA 00:00:00 cycle 2080 of 5000
# 22:17:14 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:17:15  20% ETA 00:00:00 cycle 2036 of 10000
# 22:17:15 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure                                    | seconds
# Auto-correlation time                      | 0.00123681
# Average order                              | 0.000232526
# Average sign                               | 0.000239073
# Density Matrix for local static observable | 0.00704572
# G_tau measure                              | 0.00120458
# Total measure time                         | 0.00995871
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.110561
#   Move  Insert Delta_up: 0.109202
#   Move  Insert Delta_down: 0.111918
# Move set Remove two operators: 0.109827
#   Move  Remove Delta_up: 0.109992
#   Move  Remove Delta_dow
#
# Iteration = 7 / 10
# n: 0.109661
# Move set Insert four operators: 0.0176737
#   Move  Insert Delta_up_up: 0.0221475
#   Move  Insert Delta_up_down: 0.0147846
#   Move  Insert Delta_down_up: 0.0149307
#   Move  Insert Delta_down_down: 0.0187887
# Move set Remove four operators: 0.0183373
#   Move  Remove Delta_up_up: 0.0213739
#   Move  Remove Delta_up_down: 0.016062
#   Move  Remove Delta_down_up: 0.0154364
#   Move  Remove Delta_down_down: 0.0204676
# Move  Shift one operator: 0.692095
# [Rank 0] Warmup lasted: 0.240055 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.492368 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 5.2514
# Auto-correlation time: 1.85716
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# 8*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:17:15  41% ETA 00:00:00 cycle 2064 of 5000
# 22:17:15 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:17:15  20% ETA 00:00:00 cycle 2036 of 10000
# 22:17:16 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure                                    | seconds
# Auto-correlation time                      | 0.00126391
# Average order                              | 0.000233245
# Average sign                               | 0.000238921
# Density Matrix for local static observable | 0.007073
# G_tau measure                              | 0.00122308
# Total measure time                         | 0.0100322
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.110989
#   Move  Insert Delta_up: 0.110587
#   Move  Insert Delta_down: 0.111389
# Move set Remove two operators: 0.110049
#   Move  Remove Delta_up: 0.110856
#   Move  Remove Delta_down: 0.109244
# Move set Insert four operators: 0.0173146
#   Move  Insert Delta_up_up: 0.0208897
#   Move  Insert Delta_up_down: 0.015055
#   Move  Insert Delta_down_up: 0.0141914
#   Move  Insert Delta_down_down: 0.0191214
# Move set Remove four operators: 0.0179761
#   Move  Remove Delta_up_up: 0.020939
#   Move  Remove Delta_up_down: 0.0149873
#   Move  Remove Delta_down_up: 0.014618
#   Move  Remove Delta_down_down: 0.0213865
# Move  Shift one operator: 0.694111
# [Rank 0] Warmup lasted: 0.240866 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.49168 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 5.2405
# Auto-correlation time: 1.99174
#
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# 8*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:17:16  41% ETA 00:00:00 cycle 2094 of 5000
# 22:17:16 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:17:16  20% ETA 00:00:00 cycle 2020 of 10000
# 22:17:16 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure                                    | seconds
# Auto-correlation time                      | 0.00125237
# Average order                              | 0.000230109
# Average sign                               | 0.000238439
# Density Matrix for local static observable | 0.00708876
# G_tau measure                              | 0.00121814
# Total measure time                         | 0.0100278
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators
# : 0.110899
#   Move  Insert Delta_up: 0.111631
#   Move  Insert Delta_down: 0.110167
# Move set Remove two operators: 0.110791
#   Move  Remove Delta_up: 0.111327
#   Move  Remove Delta_down: 0.110255
# Move set Insert four operators: 0.0184581
#   Move  Insert Delta_up_up: 0.02059
#   Move  Insert Delta_up_down: 0.0163011
#   Move  Insert Delta_down_up: 0.0167051
#   Move  Insert Delta_down_down: 0.0202421
# Move set Remove four operators: 0.0185551
#   Move  Remove Delta_up_up: 0.0214838
#   Move  Remove Delta_up_down: 0.0154171
#   Move  Remove Delta_down_up: 0.0164331
#   Move  Remove Delta_down_down: 0.020902
# Move  Shift one operator: 0.692638
# [Rank 0] Warmup lasted: 0.241067 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.493559 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 5.2332
# Auto-correlation time: 2.37348
#
#
# Iteration = 8 / 10
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# 8*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:17:17  41% ETA 00:00:00 cycle 2097 of 5000
# 22:17:17 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:17:17  20% ETA 00:00:00 cycle 2041 of 10000
# 22:17:17 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure                                    | seconds
# Auto-correlation time                      | 0.00125425
# Average order                              | 0.000229934
# Average sign                               | 0.000237031
# Density Matrix for local static observable | 0.00702943
# G_tau measure                              | 0.00243889
# Total measure time                         | 0.0111895
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.112368
#   Move  Insert Delta_up: 0.112974
#   Move  Insert Delta_down: 0.111762
# Move set Remove two operators: 0.11095
#   Move  Remove Delta_up: 0.111053
#   Move  Remove Delta_down
#
# Iteration = 9 / 10
# : 0.110847
# Move set Insert four operators: 0.017829
#   Move  Insert Delta_up_up: 0.0187955
#   Move  Insert Delta_up_down: 0.0155323
#   Move  Insert Delta_down_up: 0.0172844
#   Move  Insert Delta_down_down: 0.0197268
# Move set Remove four operators: 0.0190412
#   Move  Remove Delta_up_up: 0.0224737
#   Move  Remove Delta_up_down: 0.0170167
#   Move  Remove Delta_down_up: 0.0136635
#   Move  Remove Delta_down_down: 0.0230396
# Move  Shift one operator: 0.690156
# [Rank 0] Warmup lasted: 0.240459 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.493103 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 5.1725
# Auto-correlation time: 1.63606
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# 8*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:17:17  41% ETA 00:00:00 cycle 2095 of 5000
# 22:17:17 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:17:18  20% ETA 00:00:00 cycle 2031 of 10000
# 22:17:18 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure                                    | seconds
# Auto-correlation time                      | 0.00124662
# Average order                              | 0.000231925
# Average sign                               | 0.000237423
# Density Matrix for local static observable | 0.0070805
# G_tau measure                              | 0.00234266
# Total measure time                         | 0.0111391
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.112145
#   Move  Insert Delta_up: 0.113167
#   Move  Insert Delta_down: 0.111122
# Move set Remove two operators: 0.112543
#   Move  Remove Delta_up: 0.113525
#   Move  Remove Delta_dow
#
# Iteration = 10 / 10
# n: 0.111559
# Move set Insert four operators: 0.018271
#   Move  Insert Delta_up_up: 0.0211031
#   Move  Insert Delta_up_down: 0.0149723
#   Move  Insert Delta_down_up: 0.0161968
#   Move  Insert Delta_down_down: 0.0207869
# Move set Remove four operators: 0.0182414
#   Move  Remove Delta_up_up: 0.0213537
#   Move  Remove Delta_up_down: 0.016067
#   Move  Remove Delta_down_up: 0.0147265
#   Move  Remove Delta_down_down: 0.0208661
# Move  Shift one operator: 0.691019
# [Rank 0] Warmup lasted: 0.241018 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.494057 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 5.151
# Auto-correlation time: 5.55003
# ╔╦╗╦═╗╦╔═╗ ╔═╗  ┌─┐┌┬┐┬ ┬┬ ┬┌┐
#  ║ ╠╦╝║║═╬╗╚═╗  │   │ ├─┤└┬┘├┴┐
#  ╩ ╩╚═╩╚═╝╚╚═╝  └─┘ ┴ ┴ ┴ ┴ └─┘
#
# The local Hamiltonian of the problem:
# 8*c_dag('down',0)*c_dag('up',0)*c('up',0)*c('down',0)
# Using autopartition algorithm to partition the local Hilbert space
# Found 4 subspaces.
#
# Warming up ...
# 22:17:18  41% ETA 00:00:00 cycle 2093 of 5000
# 22:17:18 100% ETA 00:00:00 cycle 4999 of 5000
#
#
#
# Accumulating ...
# 22:17:18  20% ETA 00:00:00 cycle 2041 of 10000
# 22:17:19 100% ETA 00:00:00 cycle 9999 of 10000
#
#
# [Rank 0] Collect results: Waiting for all mpi-threads to finish accumulating...
# [Rank 0] Timings for all measures:
# Measure                                    | seconds
# Auto-correlation time                      | 0.00124421
# Average order                              | 0.000230008
# Average sign                               | 0.000238227
# Density Matrix for local static observable | 0.00705757
# G_tau measure                              | 0.00134457
# Total measure time                         | 0.0101146
# [Rank 0] Acceptance rate for all moves:
# Move set Insert two operators: 0.112352
#   Move  Insert Delta_up: 0.114504
#   Move  Insert Delta_down: 0.110191
# Move set Remove two operators: 0.110878
#   Move  Remove Delta_up: 0.111928
#   Move  Remove Delta_down: 0.109828
# Move set Insert four operators: 0.0176968
#   Move  Insert Delta_up_up: 0.0203682
#   Move  Insert Delta_up_down: 0.014656
#   Move  Insert Delta_down_up: 0.0156879
#   Move  Insert Delta_down_down: 0.0200681
# Move set Remove four operators: 0.0184946
#   Move  Remove Delta_up_up: 0.0230185
#   Move  Remove Delta_up_down: 0.0167861
#   Move  Remove Delta_down_up: 0.014314
#   Move  Remove Delta_down_down: 0.019847
# Move  Shift one operator: 0.690939
# [Rank 0] Warmup lasted: 0.240922 seconds [00:00:00]
# [Rank 0] Simulation lasted: 0.490586 seconds [00:00:00]
# [Rank 0] Number of measures: 10000
# Total number of measures: 10000
# Average sign: 1
# Average order: 5.1427
# Auto-correlation time: 3.12865

# %%
# import and use multiplet analysis function to get panda data frame of the impurity multiplets
from triqs_cthyb.multiplet_tools import multiplet_analysis

# %%
# using now the multiplet analysis function to obtain a panda data frame of the occupied multiplets
res_met = multiplet_analysis(rho = solver_U_met.density_matrix,
                             h_loc_diag = solver_U_met.h_loc_diagonalization,
                             # one orbital
                             n_orb = 1,
                             # two spin channels
                             spin_names = ['up','down'])
res_met
# Out:
#    Sub#  EV#  N  energy      prob    S2  m_s  |m_s|         state
# 0     0    0  1     0.0  0.349873  0.75  0.5    0.5   +1.0000|01>
# 1     1    0  1     0.0  0.326986  0.75 -0.5    0.5   +1.0000|10>
# 2     2    0  0     1.0  0.161091  0.00  0.0    0.0   +1.0000|00>
# 3     3    0  2     1.0  0.162049  0.00  0.0    0.0   +1.0000|11>

# %%
res_ins = multiplet_analysis(rho = solver_U_ins.density_matrix,
                             h_loc_diag = solver_U_ins.h_loc_diagonalization,
                             n_orb = 1,
                             spin_names = ['up','down'])
res_ins
# Out:
#    Sub#  EV#  N  energy      prob    S2  m_s  |m_s|         state
# 0     0    0  0     0.0  0.448025  0.00  0.0    0.0   +1.0000|00>
# 1     1    0  1     0.0  0.291907  0.75  0.5    0.5   +1.0000|01>
# 2     2    0  1     0.0  0.254284  0.75 -0.5    0.5   +1.0000|10>
# 3     3    0  2     8.0  0.005784  0.00  0.0    0.0   +1.0000|11>

# %% [markdown]
# We observe that in the insulating state only the high spin states with $m_s= \pm 0.5$ are occupied, while in the metallic state also the low spin states with $m_s=0.0$ are occupied. We can also see that their relative energy eigenvalues within the impurity change when U is varied.
