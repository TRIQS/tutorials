# %% [markdown]
# # FermiSee
#
# To visualize and explore the spectral properties of materials more interactively we developed the WebApp [FermiSee](https://github.com/TRIQS/FermiSee). In this part of the tutorial we will learn how to use FermiSee and explore its functionality. The App can be accessed via a hosted version at the [Flatiron Institute](http://fermisee.flatironinstitute.org).
#
# Example tutorials can be found on the github page [FermiSee](https://github.com/TRIQS/FermiSee)

# %% [markdown]
# FermiSee is used by accessing it via [fermisee.flatironinstitute.org](http://fermisee.flatironinstitute.org/) . You should also copy the output files `lco_hr.dat`, `lco.wout`, and `simga_fermisee.h5` to your local machine via the web interface of jupyter lab by right-clicking on them in in the file explorer -> download.
#
# 1. Load the `lco_hr.dat` and the `lco.wout` from the `data/mlwf` directory in the `TB Hamiltonian` section and calculate the bands
# 2. calculate the correct `mu` by entering the correct filling of the model. Here, we have one electron per Cu site.
# 3. The bands should be now recomputed and centered around 0
# 4. change the kpoint path to the same path used in the previous notebook
# 5. download the config (for safety)
# 6. expand now the self-energy section by clicking on it
# 7. upload the `sigma_fermisee.h5` file and click `Calculate A(k,w)`, after a few seconds the spectral function should appear
# 8. feel free to explore the other features now and answer the questions below
#
# If anything goes wrong, reload and upload on the top your previously downloaded config file.

# %% [markdown]
# <i class="fa fa-gear fa-2x" style="color: #186391"></i>&nbsp; cross check the quasiparticle weight extracted from solid_dmft with FermiSee by using the manual self-energy option. Try to find the best fit to the quasiparticle band from DMFT by choosing Z appropriately via the manual sigma interface in FermiSee:
#
# ![image.png](attachment:2e9cacdf-3b2a-4f36-8df2-63d02de7a891.png)
#
# increase $\eta$ to 0.1 and reduce Z to something like 0.2 or 0.25:
#
# ![newplot.png](attachment:c321d184-e8b1-48fe-8d16-1f196950735b.png)

# %% [markdown]
# <i class="fa fa-gear fa-2x" style="color: #186391"></i>&nbsp; Explain why there the incoherent part of the spectrum is missing in this quasiparticle approach.
#
# > The quasiparticle features in the Fermi liquid regime is a linear approximation around the Fermi level and therefore does not capture incoherent parts of the spectrum.
#
# <i class="fa fa-gear fa-2x" style="color: #186391"></i>&nbsp; Try to do a Fermi surface A(k,0) plot on the second tab of FermiSee. To do so, you need to be able to see the spectral function on the first tab before switching to the second tab.
# ![image.png](attachment:b1e80e57-4eac-47f8-99d3-186c2af88249.png)
